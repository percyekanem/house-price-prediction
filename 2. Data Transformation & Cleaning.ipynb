# %% [markdown]
# # Importing data/libraries

# %%
from MySQLConnect import mysql_engine
import pandas as pd
import numpy as np
from pandasql import sqldf

# %%
engine = mysql_engine() #creating an instance of the SQL connection engine from the central module.

# %%
uk_hp_index = pd.read_sql("select * from uk_house_price_index", engine)

# %%
uk_hp_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136125 entries, 0 to 136124
# Data columns (total 57 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Date                    136125 non-null  object
#  1   RegionName              136125 non-null  object
#  2   AreaCode                136125 non-null  object
#  3   AveragePrice            136125 non-null  float64
#  4   Index                   136125 non-null  float64
#  5   IndexSA                 4764 non-null    float64
#  6   1m%Change               135702 non-null  float64
#  7   12m%Change              131325 non-null  float64
#  8   AveragePriceSA          4764 non-null    float64
#  9   SalesVolume             131658 non-null  float64
#  10  DetachedPrice           129708 non-null  float64
#  11  DetachedIndex           129708 non-null  float64
#  12  Detached1m%Change       129319 non-null  float64
#  13  Detached12m%Change      125064 non-null  float64
#  14  SemiDetachedPrice       129708 non-null  float64
#  15  SemiDetachedIndex       129708 non-null  float64
#  16  SemiDetached1m%Change   129319 non-null  float64
#  17  SemiDetached12m%Change  125064 non-null  float64
#  18  TerracedPrice           129735 non-null  float64
#  19  TerracedIndex           129735 non-null  float64
#  20  Terraced1m%Change       129346 non-null  float64
#  21  Terraced12m%Change      125091 non-null  float64
#  22  FlatPrice               130048 non-null  float64
#  23  FlatIndex               130048 non-null  float64
#  24  Flat1m%Change           129658 non-null  float64
#  25  Flat12m%Change          125392 non-null  float64
#  26  CashPrice               53312 non-null   float64
#  27  CashIndex               53312 non-null   float64
#  28  Cash1m%Change           52922 non-null   float64
#  29  Cash12m%Change          48632 non-null   float64
#  30  CashSalesVolume         52526 non-null   float64
#  31  MortgagePrice           53312 non-null   float64
#  32  MortgageIndex           53312 non-null   float64
#  33  Mortgage1m%Change       52922 non-null   float64
#  34  Mortgage12m%Change      48632 non-null   float64
#  35  MortgageSalesVolume     52527 non-null   float64
#  36  FTBPrice                53708 non-null   float64
#  37  FTBIndex                53708 non-null   float64
#  38  FTB1m%Change            53318 non-null   float64
#  39  FTB12m%Change           49028 non-null   float64
#  40  FOOPrice                53312 non-null   float64
#  41  FOOIndex                53312 non-null   float64
#  42  FOO1m%Change            52922 non-null   float64
#  43  FOO12m%Change           48632 non-null   float64
#  44  NewPrice                129019 non-null  float64
#  45  NewIndex                129223 non-null  float64
#  46  New1m%Change            128833 non-null  float64
#  47  New12m%Change           124567 non-null  float64
#  48  NewSalesVolume          127557 non-null  float64
#  49  OldPrice                129260 non-null  float64
#  50  OldIndex                129260 non-null  float64
#  51  Old1m%Change            128870 non-null  float64
#  52  Old12m%Change           124604 non-null  float64
#  53  OldSalesVolume          129248 non-null  float64
#  54  Country                 136125 non-null  object
#  55  state                   136125 non-null  object
#  56  county                  105445 non-null  object
# dtypes: float64(51), object(6)
# memory usage: 59.2+ MB

# %% [markdown]
# ## Fixing error in locations

# %% [markdown]
# > Locations with the region "United Kingdom" all have their state as "England". They'll be replaced here.

# %%
uk_hp_index.loc[uk_hp_index["RegionName"]=="United Kingdom", "state"] = np.nan
#Assigning NA to the state column where region name is "United Kingdom"

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ## Renaming columns for compatibility

# %% [markdown]
# >  Replacing "index" with "PriceIndex" to remove ambiguity, removing "%" from column names

# %%
uk_hp_index.columns = uk_hp_index.columns.str.replace('Index', 'PriceIndex')
uk_hp_index.columns = uk_hp_index.columns.str.replace('%', '')

# %% [markdown]
# ## Formatting the Date column

# %%
uk_hp_index[["Date"]].head()
# Out:
#          Date
# 0  01/01/2004
# 1  01/02/2004
# 2  01/03/2004
# 3  01/04/2004
# 4  01/05/2004

# %%
uk_hp_index["Date"] = pd.to_datetime(uk_hp_index["Date"], format="%d/%m/%Y") #converting "Date" from object to datetime.

# %%
max(uk_hp_index["Date"]) #records end in April 2023
# Out:
# Timestamp('2023-04-01 00:00:00')

# %%
min(uk_hp_index["Date"]) #records start in April 1968
# Out:
# Timestamp('1968-04-01 00:00:00')

# %%
pd.unique(uk_hp_index["Date"])
# Out:
# array(['2004-01-01T00:00:00.000000000', '2004-02-01T00:00:00.000000000',
#        '2004-03-01T00:00:00.000000000', '2004-04-01T00:00:00.000000000',
#        '2004-05-01T00:00:00.000000000', '2004-06-01T00:00:00.000000000',
#        '2004-07-01T00:00:00.000000000', '2004-08-01T00:00:00.000000000',
#        '2004-09-01T00:00:00.000000000', '2004-10-01T00:00:00.000000000',
#        '2004-11-01T00:00:00.000000000', '2004-12-01T00:00:00.000000000',
#        '2005-01-01T00:00:00.000000000', '2005-02-01T00:00:00.000000000',
#        '2005-03-01T00:00:00.000000000', '2005-04-01T00:00:00.000000000',
#        '2005-05-01T00:00:00.000000000', '2005-06-01T00:00:00.000000000',
#        '2005-07-01T00:00:00.000000000', '2005-08-01T00:00:00.000000000',
#        '2005-09-01T00:00:00.000000000', '2005-10-01T00:00:00.000000000',
#        '2005-11-01T00:00:00.000000000', '2005-12-01T00:00:00.000000000',
#        '2006-01-01T00:00:00.000000000', '2006-02-01T00:00:00.000000000',
#        '2006-03-01T00:00:00.000000000', '2006-04-01T00:00:00.000000000',
#        '2006-05-01T00:00:00.000000000', '2006-06-01T00:00:00.000000000',
#        '2006-07-01T00:00:00.000000000', '2006-08-01T00:00:00.000000000',
#        '2006-09-01T00:00:00.000000000', '2006-10-01T00:00:00.000000000',
#        '2006-11-01T00:00:00.000000000', '2006-12-01T00:00:00.000000000',
#        '2007-01-01T00:00:00.000000000', '2007-02-01T00:00:00.000000000',
#        '2007-03-01T00:00:00.000000000', '2007-04-01T00:00:00.000000000',
#        '2007-05-01T00:00:00.000000000', '2007-06-01T00:00:00.000000000',
#        '2007-07-01T00:00:00.000000000', '2007-08-01T00:00:00.000000000',
#        '2007-09-01T00:00:00.000000000', '2007-10-01T00:00:00.000000000',
#        '2007-11-01T00:00:00.000000000', '2007-12-01T00:00:00.000000000',
#        '2008-01-01T00:00:00.000000000', '2008-02-01T00:00:00.000000000',
#        '2008-03-01T00:00:00.000000000', '2008-04-01T00:00:00.000000000',
#        '2008-05-01T00:00:00.000000000', '2008-06-01T00:00:00.000000000',
#        '2008-07-01T00:00:00.000000000', '2008-08-01T00:00:00.000000000',
#        '2008-09-01T00:00:00.000000000', '2008-10-01T00:00:00.000000000',
#        '2008-11-01T00:00:00.000000000', '2008-12-01T00:00:00.000000000',
#        '2009-01-01T00:00:00.000000000', '2009-02-01T00:00:00.000000000',
#        '2009-03-01T00:00:00.000000000', '2009-04-01T00:00:00.000000000',
#        '2009-05-01T00:00:00.000000000', '2009-06-01T00:00:00.000000000',
#        '2009-07-01T00:00:00.000000000', '2009-08-01T00:00:00.000000000',
#        '2009-09-01T00:00:00.000000000', '2009-10-01T00:00:00.000000000',
#        '2009-11-01T00:00:00.000000000', '2009-12-01T00:00:00.000000000',
#        '2010-01-01T00:00:00.000000000', '2010-02-01T00:00:00.000000000',
#        '2010-03-01T00:00:00.000000000', '2010-04-01T00:00:00.000000000',
#        '2010-05-01T00:00:00.000000000', '2010-06-01T00:00:00.000000000',
#        '2010-07-01T00:00:00.000000000', '2010-08-01T00:00:00.000000000',
#        '2010-09-01T00:00:00.000000000', '2010-10-01T00:00:00.000000000',
#        '2010-11-01T00:00:00.000000000', '2010-12-01T00:00:00.000000000',
#        '2011-01-01T00:00:00.000000000', '2011-02-01T00:00:00.000000000',
#        '2011-03-01T00:00:00.000000000', '2011-04-01T00:00:00.000000000',
#        '2011-05-01T00:00:00.000000000', '2011-06-01T00:00:00.000000000',
#        '2011-07-01T00:00:00.000000000', '2011-08-01T00:00:00.000000000',
#        '2011-09-01T00:00:00.000000000', '2011-10-01T00:00:00.000000000',
#        '2011-11-01T00:00:00.000000000', '2011-12-01T00:00:00.000000000',
#        '2012-01-01T00:00:00.000000000', '2012-02-01T00:00:00.000000000',
#        '2012-03-01T00:00:00.000000000', '2012-04-01T00:00:00.000000000',
#        '2012-05-01T00:00:00.000000000', '2012-06-01T00:00:00.000000000',
#        '2012-07-01T00:00:00.000000000', '2012-08-01T00:00:00.000000000',
#        '2012-09-01T00:00:00.000000000', '2012-10-01T00:00:00.000000000',
#        '2012-11-01T00:00:00.000000000', '2012-12-01T00:00:00.000000000',
#        '2013-01-01T00:00:00.000000000', '2013-02-01T00:00:00.000000000',
#        '2013-03-01T00:00:00.000000000', '2013-04-01T00:00:00.000000000',
#        '2013-05-01T00:00:00.000000000', '2013-06-01T00:00:00.000000000',
#        '2013-07-01T00:00:00.000000000', '2013-08-01T00:00:00.000000000',
#        '2013-09-01T00:00:00.000000000', '2013-10-01T00:00:00.000000000',
#        '2013-11-01T00:00:00.000000000', '2013-12-01T00:00:00.000000000',
#        '2014-01-01T00:00:00.000000000', '2014-02-01T00:00:00.000000000',
#        '2014-03-01T00:00:00.000000000', '2014-04-01T00:00:00.000000000',
#        '2014-05-01T00:00:00.000000000', '2014-06-01T00:00:00.000000000',
#        '2014-07-01T00:00:00.000000000', '2014-08-01T00:00:00.000000000',
#        '2014-09-01T00:00:00.000000000', '2014-10-01T00:00:00.000000000',
#        '2014-11-01T00:00:00.000000000', '2014-12-01T00:00:00.000000000',
#        '2015-01-01T00:00:00.000000000', '2015-02-01T00:00:00.000000000',
#        '2015-03-01T00:00:00.000000000', '2015-04-01T00:00:00.000000000',
#        '2015-05-01T00:00:00.000000000', '2015-06-01T00:00:00.000000000',
#        '2015-07-01T00:00:00.000000000', '2015-08-01T00:00:00.000000000',
#        '2015-09-01T00:00:00.000000000', '2015-10-01T00:00:00.000000000',
#        '2015-11-01T00:00:00.000000000', '2015-12-01T00:00:00.000000000',
#        '2016-01-01T00:00:00.000000000', '2016-02-01T00:00:00.000000000',
#        '2016-03-01T00:00:00.000000000', '2016-04-01T00:00:00.000000000',
#        '2016-05-01T00:00:00.000000000', '2016-06-01T00:00:00.000000000',
#        '2016-07-01T00:00:00.000000000', '2016-08-01T00:00:00.000000000',
#        '2016-09-01T00:00:00.000000000', '2016-10-01T00:00:00.000000000',
#        '2016-11-01T00:00:00.000000000', '2016-12-01T00:00:00.000000000',
#        '2017-01-01T00:00:00.000000000', '2017-02-01T00:00:00.000000000',
#        '2017-03-01T00:00:00.000000000', '2017-04-01T00:00:00.000000000',
#        '2017-05-01T00:00:00.000000000', '2017-06-01T00:00:00.000000000',
#        '2017-07-01T00:00:00.000000000', '2017-08-01T00:00:00.000000000',
#        '2017-09-01T00:00:00.000000000', '2017-10-01T00:00:00.000000000',
#        '2017-11-01T00:00:00.000000000', '2017-12-01T00:00:00.000000000',
#        '2018-01-01T00:00:00.000000000', '2018-02-01T00:00:00.000000000',
#        '2018-03-01T00:00:00.000000000', '2018-04-01T00:00:00.000000000',
#        '2018-05-01T00:00:00.000000000', '2018-06-01T00:00:00.000000000',
#        '2018-07-01T00:00:00.000000000', '2018-08-01T00:00:00.000000000',
#        '2018-09-01T00:00:00.000000000', '2018-10-01T00:00:00.000000000',
#        '2018-11-01T00:00:00.000000000', '2018-12-01T00:00:00.000000000',
#        '2019-01-01T00:00:00.000000000', '2019-02-01T00:00:00.000000000',
#        '2019-03-01T00:00:00.000000000', '2019-04-01T00:00:00.000000000',
#        '2019-05-01T00:00:00.000000000', '2019-06-01T00:00:00.000000000',
#        '2019-07-01T00:00:00.000000000', '2019-08-01T00:00:00.000000000',
#        '2019-09-01T00:00:00.000000000', '2019-10-01T00:00:00.000000000',
#        '2019-11-01T00:00:00.000000000', '2019-12-01T00:00:00.000000000',
#        '2020-01-01T00:00:00.000000000', '2020-02-01T00:00:00.000000000',
#        '2020-03-01T00:00:00.000000000', '2020-04-01T00:00:00.000000000',
#        '2020-05-01T00:00:00.000000000', '2020-06-01T00:00:00.000000000',
#        '2020-07-01T00:00:00.000000000', '2020-08-01T00:00:00.000000000',
#        '2020-09-01T00:00:00.000000000', '2020-10-01T00:00:00.000000000',
#        '2020-11-01T00:00:00.000000000', '2020-12-01T00:00:00.000000000',
#        '2021-01-01T00:00:00.000000000', '2021-02-01T00:00:00.000000000',
#        '2021-03-01T00:00:00.000000000', '2021-04-01T00:00:00.000000000',
#        '2021-05-01T00:00:00.000000000', '2021-06-01T00:00:00.000000000',
#        '2021-07-01T00:00:00.000000000', '2021-08-01T00:00:00.000000000',
#        '2021-09-01T00:00:00.000000000', '2021-10-01T00:00:00.000000000',
#        '2021-11-01T00:00:00.000000000', '2021-12-01T00:00:00.000000000',
#        '2022-01-01T00:00:00.000000000', '2022-02-01T00:00:00.000000000',
#        '2022-03-01T00:00:00.000000000', '2022-04-01T00:00:00.000000000',
#        '2022-05-01T00:00:00.000000000', '2022-06-01T00:00:00.000000000',
#        '2022-07-01T00:00:00.000000000', '2022-08-01T00:00:00.000000000',
#        '2022-09-01T00:00:00.000000000', '2022-10-01T00:00:00.000000000',
#        '2022-11-01T00:00:00.000000000', '2022-12-01T00:00:00.000000000',
#        '2023-01-01T00:00:00.000000000', '2023-02-01T00:00:00.000000000',
#        '2023-03-01T00:00:00.000000000', '2023-04-01T00:00:00.000000000',
#        '1995-01-01T00:00:00.000000000', '1995-02-01T00:00:00.000000000',
#        '1995-03-01T00:00:00.000000000', '1995-04-01T00:00:00.000000000',
#        '1995-05-01T00:00:00.000000000', '1995-06-01T00:00:00.000000000',
#        '1995-07-01T00:00:00.000000000', '1995-08-01T00:00:00.000000000',
#        '1995-09-01T00:00:00.000000000', '1995-10-01T00:00:00.000000000',
#        '1995-11-01T00:00:00.000000000', '1995-12-01T00:00:00.000000000',
#        '1996-01-01T00:00:00.000000000', '1996-02-01T00:00:00.000000000',
#        '1996-03-01T00:00:00.000000000', '1996-04-01T00:00:00.000000000',
#        '1996-05-01T00:00:00.000000000', '1996-06-01T00:00:00.000000000',
#        '1996-07-01T00:00:00.000000000', '1996-08-01T00:00:00.000000000',
#        '1996-09-01T00:00:00.000000000', '1996-10-01T00:00:00.000000000',
#        '1996-11-01T00:00:00.000000000', '1996-12-01T00:00:00.000000000',
#        '1997-01-01T00:00:00.000000000', '1997-02-01T00:00:00.000000000',
#        '1997-03-01T00:00:00.000000000', '1997-04-01T00:00:00.000000000',
#        '1997-05-01T00:00:00.000000000', '1997-06-01T00:00:00.000000000',
#        '1997-07-01T00:00:00.000000000', '1997-08-01T00:00:00.000000000',
#        '1997-09-01T00:00:00.000000000', '1997-10-01T00:00:00.000000000',
#        '1997-11-01T00:00:00.000000000', '1997-12-01T00:00:00.000000000',
#        '1998-01-01T00:00:00.000000000', '1998-02-01T00:00:00.000000000',
#        '1998-03-01T00:00:00.000000000', '1998-04-01T00:00:00.000000000',
#        '1998-05-01T00:00:00.000000000', '1998-06-01T00:00:00.000000000',
#        '1998-07-01T00:00:00.000000000', '1998-08-01T00:00:00.000000000',
#        '1998-09-01T00:00:00.000000000', '1998-10-01T00:00:00.000000000',
#        '1998-11-01T00:00:00.000000000', '1998-12-01T00:00:00.000000000',
#        '1999-01-01T00:00:00.000000000', '1999-02-01T00:00:00.000000000',
#        '1999-03-01T00:00:00.000000000', '1999-04-01T00:00:00.000000000',
#        '1999-05-01T00:00:00.000000000', '1999-06-01T00:00:00.000000000',
#        '1999-07-01T00:00:00.000000000', '1999-08-01T00:00:00.000000000',
#        '1999-09-01T00:00:00.000000000', '1999-10-01T00:00:00.000000000',
#        '1999-11-01T00:00:00.000000000', '1999-12-01T00:00:00.000000000',
#        '2000-01-01T00:00:00.000000000', '2000-02-01T00:00:00.000000000',
#        '2000-03-01T00:00:00.000000000', '2000-04-01T00:00:00.000000000',
#        '2000-05-01T00:00:00.000000000', '2000-06-01T00:00:00.000000000',
#        '2000-07-01T00:00:00.000000000', '2000-08-01T00:00:00.000000000',
#        '2000-09-01T00:00:00.000000000', '2000-10-01T00:00:00.000000000',
#        '2000-11-01T00:00:00.000000000', '2000-12-01T00:00:00.000000000',
#        '2001-01-01T00:00:00.000000000', '2001-02-01T00:00:00.000000000',
#        '2001-03-01T00:00:00.000000000', '2001-04-01T00:00:00.000000000',
#        '2001-05-01T00:00:00.000000000', '2001-06-01T00:00:00.000000000',
#        '2001-07-01T00:00:00.000000000', '2001-08-01T00:00:00.000000000',
#        '2001-09-01T00:00:00.000000000', '2001-10-01T00:00:00.000000000',
#        '2001-11-01T00:00:00.000000000', '2001-12-01T00:00:00.000000000',
#        '2002-01-01T00:00:00.000000000', '2002-02-01T00:00:00.000000000',
#        '2002-03-01T00:00:00.000000000', '2002-04-01T00:00:00.000000000',
#        '2002-05-01T00:00:00.000000000', '2002-06-01T00:00:00.000000000',
#        '2002-07-01T00:00:00.000000000', '2002-08-01T00:00:00.000000000',
#        '2002-09-01T00:00:00.000000000', '2002-10-01T00:00:00.000000000',
#        '2002-11-01T00:00:00.000000000', '2002-12-01T00:00:00.000000000',
#        '2003-01-01T00:00:00.000000000', '2003-02-01T00:00:00.000000000',
#        '2003-03-01T00:00:00.000000000', '2003-04-01T00:00:00.000000000',
#        '2003-05-01T00:00:00.000000000', '2003-06-01T00:00:00.000000000',
#        '2003-07-01T00:00:00.000000000', '2003-08-01T00:00:00.000000000',
#        '2003-09-01T00:00:00.000000000', '2003-10-01T00:00:00.000000000',
#        '2003-11-01T00:00:00.000000000', '2003-12-01T00:00:00.000000000',
#        '1968-04-01T00:00:00.000000000', '1968-05-01T00:00:00.000000000',
#        '1968-06-01T00:00:00.000000000', '1968-07-01T00:00:00.000000000',
#        '1968-08-01T00:00:00.000000000', '1968-09-01T00:00:00.000000000',
#        '1968-10-01T00:00:00.000000000', '1968-11-01T00:00:00.000000000',
#        '1968-12-01T00:00:00.000000000', '1969-01-01T00:00:00.000000000',
#        '1969-02-01T00:00:00.000000000', '1969-03-01T00:00:00.000000000',
#        '1969-04-01T00:00:00.000000000', '1969-05-01T00:00:00.000000000',
#        '1969-06-01T00:00:00.000000000', '1969-07-01T00:00:00.000000000',
#        '1969-08-01T00:00:00.000000000', '1969-09-01T00:00:00.000000000',
#        '1969-10-01T00:00:00.000000000', '1969-11-01T00:00:00.000000000',
#        '1969-12-01T00:00:00.000000000', '1970-01-01T00:00:00.000000000',
#        '1970-02-01T00:00:00.000000000', '1970-03-01T00:00:00.000000000',
#        '1970-04-01T00:00:00.000000000', '1970-05-01T00:00:00.000000000',
#        '1970-06-01T00:00:00.000000000', '1970-07-01T00:00:00.000000000',
#        '1970-08-01T00:00:00.000000000', '1970-09-01T00:00:00.000000000',
#        '1970-10-01T00:00:00.000000000', '1970-11-01T00:00:00.000000000',
#        '1970-12-01T00:00:00.000000000', '1971-01-01T00:00:00.000000000',
#        '1971-02-01T00:00:00.000000000', '1971-03-01T00:00:00.000000000',
#        '1971-04-01T00:00:00.000000000', '1971-05-01T00:00:00.000000000',
#        '1971-06-01T00:00:00.000000000', '1971-07-01T00:00:00.000000000',
#        '1971-08-01T00:00:00.000000000', '1971-09-01T00:00:00.000000000',
#        '1971-10-01T00:00:00.000000000', '1971-11-01T00:00:00.000000000',
#        '1971-12-01T00:00:00.000000000', '1972-01-01T00:00:00.000000000',
#        '1972-02-01T00:00:00.000000000', '1972-03-01T00:00:00.000000000',
#        '1972-04-01T00:00:00.000000000', '1972-05-01T00:00:00.000000000',
#        '1972-06-01T00:00:00.000000000', '1972-07-01T00:00:00.000000000',
#        '1972-08-01T00:00:00.000000000', '1972-09-01T00:00:00.000000000',
#        '1972-10-01T00:00:00.000000000', '1972-11-01T00:00:00.000000000',
#        '1972-12-01T00:00:00.000000000', '1973-01-01T00:00:00.000000000',
#        '1973-02-01T00:00:00.000000000', '1973-03-01T00:00:00.000000000',
#        '1973-04-01T00:00:00.000000000', '1973-05-01T00:00:00.000000000',
#        '1973-06-01T00:00:00.000000000', '1973-07-01T00:00:00.000000000',
#        '1973-08-01T00:00:00.000000000', '1973-09-01T00:00:00.000000000',
#        '1973-10-01T00:00:00.000000000', '1973-11-01T00:00:00.000000000',
#        '1973-12-01T00:00:00.000000000', '1974-01-01T00:00:00.000000000',
#        '1974-02-01T00:00:00.000000000', '1974-03-01T00:00:00.000000000',
#        '1974-04-01T00:00:00.000000000', '1974-05-01T00:00:00.000000000',
#        '1974-06-01T00:00:00.000000000', '1974-07-01T00:00:00.000000000',
#        '1974-08-01T00:00:00.000000000', '1974-09-01T00:00:00.000000000',
#        '1974-10-01T00:00:00.000000000', '1974-11-01T00:00:00.000000000',
#        '1974-12-01T00:00:00.000000000', '1975-01-01T00:00:00.000000000',
#        '1975-02-01T00:00:00.000000000', '1975-03-01T00:00:00.000000000',
#        '1975-04-01T00:00:00.000000000', '1975-05-01T00:00:00.000000000',
#        '1975-06-01T00:00:00.000000000', '1975-07-01T00:00:00.000000000',
#        '1975-08-01T00:00:00.000000000', '1975-09-01T00:00:00.000000000',
#        '1975-10-01T00:00:00.000000000', '1975-11-01T00:00:00.000000000',
#        '1975-12-01T00:00:00.000000000', '1976-01-01T00:00:00.000000000',
#        '1976-02-01T00:00:00.000000000', '1976-03-01T00:00:00.000000000',
#        '1976-04-01T00:00:00.000000000', '1976-05-01T00:00:00.000000000',
#        '1976-06-01T00:00:00.000000000', '1976-07-01T00:00:00.000000000',
#        '1976-08-01T00:00:00.000000000', '1976-09-01T00:00:00.000000000',
#        '1976-10-01T00:00:00.000000000', '1976-11-01T00:00:00.000000000',
#        '1976-12-01T00:00:00.000000000', '1977-01-01T00:00:00.000000000',
#        '1977-02-01T00:00:00.000000000', '1977-03-01T00:00:00.000000000',
#        '1977-04-01T00:00:00.000000000', '1977-05-01T00:00:00.000000000',
#        '1977-06-01T00:00:00.000000000', '1977-07-01T00:00:00.000000000',
#        '1977-08-01T00:00:00.000000000', '1977-09-01T00:00:00.000000000',
#        '1977-10-01T00:00:00.000000000', '1977-11-01T00:00:00.000000000',
#        '1977-12-01T00:00:00.000000000', '1978-01-01T00:00:00.000000000',
#        '1978-02-01T00:00:00.000000000', '1978-03-01T00:00:00.000000000',
#        '1978-04-01T00:00:00.000000000', '1978-05-01T00:00:00.000000000',
#        '1978-06-01T00:00:00.000000000', '1978-07-01T00:00:00.000000000',
#        '1978-08-01T00:00:00.000000000', '1978-09-01T00:00:00.000000000',
#        '1978-10-01T00:00:00.000000000', '1978-11-01T00:00:00.000000000',
#        '1978-12-01T00:00:00.000000000', '1979-01-01T00:00:00.000000000',
#        '1979-02-01T00:00:00.000000000', '1979-03-01T00:00:00.000000000',
#        '1979-04-01T00:00:00.000000000', '1979-05-01T00:00:00.000000000',
#        '1979-06-01T00:00:00.000000000', '1979-07-01T00:00:00.000000000',
#        '1979-08-01T00:00:00.000000000', '1979-09-01T00:00:00.000000000',
#        '1979-10-01T00:00:00.000000000', '1979-11-01T00:00:00.000000000',
#        '1979-12-01T00:00:00.000000000', '1980-01-01T00:00:00.000000000',
#        '1980-02-01T00:00:00.000000000', '1980-03-01T00:00:00.000000000',
#        '1980-04-01T00:00:00.000000000', '1980-05-01T00:00:00.000000000',
#        '1980-06-01T00:00:00.000000000', '1980-07-01T00:00:00.000000000',
#        '1980-08-01T00:00:00.000000000', '1980-09-01T00:00:00.000000000',
#        '1980-10-01T00:00:00.000000000', '1980-11-01T00:00:00.000000000',
#        '1980-12-01T00:00:00.000000000', '1981-01-01T00:00:00.000000000',
#        '1981-02-01T00:00:00.000000000', '1981-03-01T00:00:00.000000000',
#        '1981-04-01T00:00:00.000000000', '1981-05-01T00:00:00.000000000',
#        '1981-06-01T00:00:00.000000000', '1981-07-01T00:00:00.000000000',
#        '1981-08-01T00:00:00.000000000', '1981-09-01T00:00:00.000000000',
#        '1981-10-01T00:00:00.000000000', '1981-11-01T00:00:00.000000000',
#        '1981-12-01T00:00:00.000000000', '1982-01-01T00:00:00.000000000',
#        '1982-02-01T00:00:00.000000000', '1982-03-01T00:00:00.000000000',
#        '1982-04-01T00:00:00.000000000', '1982-05-01T00:00:00.000000000',
#        '1982-06-01T00:00:00.000000000', '1982-07-01T00:00:00.000000000',
#        '1982-08-01T00:00:00.000000000', '1982-09-01T00:00:00.000000000',
#        '1982-10-01T00:00:00.000000000', '1982-11-01T00:00:00.000000000',
#        '1982-12-01T00:00:00.000000000', '1983-01-01T00:00:00.000000000',
#        '1983-02-01T00:00:00.000000000', '1983-03-01T00:00:00.000000000',
#        '1983-04-01T00:00:00.000000000', '1983-05-01T00:00:00.000000000',
#        '1983-06-01T00:00:00.000000000', '1983-07-01T00:00:00.000000000',
#        '1983-08-01T00:00:00.000000000', '1983-09-01T00:00:00.000000000',
#        '1983-10-01T00:00:00.000000000', '1983-11-01T00:00:00.000000000',
#        '1983-12-01T00:00:00.000000000', '1984-01-01T00:00:00.000000000',
#        '1984-02-01T00:00:00.000000000', '1984-03-01T00:00:00.000000000',
#        '1984-04-01T00:00:00.000000000', '1984-05-01T00:00:00.000000000',
#        '1984-06-01T00:00:00.000000000', '1984-07-01T00:00:00.000000000',
#        '1984-08-01T00:00:00.000000000', '1984-09-01T00:00:00.000000000',
#        '1984-10-01T00:00:00.000000000', '1984-11-01T00:00:00.000000000',
#        '1984-12-01T00:00:00.000000000', '1985-01-01T00:00:00.000000000',
#        '1985-02-01T00:00:00.000000000', '1985-03-01T00:00:00.000000000',
#        '1985-04-01T00:00:00.000000000', '1985-05-01T00:00:00.000000000',
#        '1985-06-01T00:00:00.000000000', '1985-07-01T00:00:00.000000000',
#        '1985-08-01T00:00:00.000000000', '1985-09-01T00:00:00.000000000',
#        '1985-10-01T00:00:00.000000000', '1985-11-01T00:00:00.000000000',
#        '1985-12-01T00:00:00.000000000', '1986-01-01T00:00:00.000000000',
#        '1986-02-01T00:00:00.000000000', '1986-03-01T00:00:00.000000000',
#        '1986-04-01T00:00:00.000000000', '1986-05-01T00:00:00.000000000',
#        '1986-06-01T00:00:00.000000000', '1986-07-01T00:00:00.000000000',
#        '1986-08-01T00:00:00.000000000', '1986-09-01T00:00:00.000000000',
#        '1986-10-01T00:00:00.000000000', '1986-11-01T00:00:00.000000000',
#        '1986-12-01T00:00:00.000000000', '1987-01-01T00:00:00.000000000',
#        '1987-02-01T00:00:00.000000000', '1987-03-01T00:00:00.000000000',
#        '1987-04-01T00:00:00.000000000', '1987-05-01T00:00:00.000000000',
#        '1987-06-01T00:00:00.000000000', '1987-07-01T00:00:00.000000000',
#        '1987-08-01T00:00:00.000000000', '1987-09-01T00:00:00.000000000',
#        '1987-10-01T00:00:00.000000000', '1987-11-01T00:00:00.000000000',
#        '1987-12-01T00:00:00.000000000', '1988-01-01T00:00:00.000000000',
#        '1988-02-01T00:00:00.000000000', '1988-03-01T00:00:00.000000000',
#        '1988-04-01T00:00:00.000000000', '1988-05-01T00:00:00.000000000',
#        '1988-06-01T00:00:00.000000000', '1988-07-01T00:00:00.000000000',
#        '1988-08-01T00:00:00.000000000', '1988-09-01T00:00:00.000000000',
#        '1988-10-01T00:00:00.000000000', '1988-11-01T00:00:00.000000000',
#        '1988-12-01T00:00:00.000000000', '1989-01-01T00:00:00.000000000',
#        '1989-02-01T00:00:00.000000000', '1989-03-01T00:00:00.000000000',
#        '1989-04-01T00:00:00.000000000', '1989-05-01T00:00:00.000000000',
#        '1989-06-01T00:00:00.000000000', '1989-07-01T00:00:00.000000000',
#        '1989-08-01T00:00:00.000000000', '1989-09-01T00:00:00.000000000',
#        '1989-10-01T00:00:00.000000000', '1989-11-01T00:00:00.000000000',
#        '1989-12-01T00:00:00.000000000', '1990-01-01T00:00:00.000000000',
#        '1990-02-01T00:00:00.000000000', '1990-03-01T00:00:00.000000000',
#        '1990-04-01T00:00:00.000000000', '1990-05-01T00:00:00.000000000',
#        '1990-06-01T00:00:00.000000000', '1990-07-01T00:00:00.000000000',
#        '1990-08-01T00:00:00.000000000', '1990-09-01T00:00:00.000000000',
#        '1990-10-01T00:00:00.000000000', '1990-11-01T00:00:00.000000000',
#        '1990-12-01T00:00:00.000000000', '1991-01-01T00:00:00.000000000',
#        '1991-02-01T00:00:00.000000000', '1991-03-01T00:00:00.000000000',
#        '1991-04-01T00:00:00.000000000', '1991-05-01T00:00:00.000000000',
#        '1991-06-01T00:00:00.000000000', '1991-07-01T00:00:00.000000000',
#        '1991-08-01T00:00:00.000000000', '1991-09-01T00:00:00.000000000',
#        '1991-10-01T00:00:00.000000000', '1991-11-01T00:00:00.000000000',
#        '1991-12-01T00:00:00.000000000', '1992-01-01T00:00:00.000000000',
#        '1992-02-01T00:00:00.000000000', '1992-03-01T00:00:00.000000000',
#        '1992-04-01T00:00:00.000000000', '1992-05-01T00:00:00.000000000',
#        '1992-06-01T00:00:00.000000000', '1992-07-01T00:00:00.000000000',
#        '1992-08-01T00:00:00.000000000', '1992-09-01T00:00:00.000000000',
#        '1992-10-01T00:00:00.000000000', '1992-11-01T00:00:00.000000000',
#        '1992-12-01T00:00:00.000000000', '1993-01-01T00:00:00.000000000',
#        '1993-02-01T00:00:00.000000000', '1993-03-01T00:00:00.000000000',
#        '1993-04-01T00:00:00.000000000', '1993-05-01T00:00:00.000000000',
#        '1993-06-01T00:00:00.000000000', '1993-07-01T00:00:00.000000000',
#        '1993-08-01T00:00:00.000000000', '1993-09-01T00:00:00.000000000',
#        '1993-10-01T00:00:00.000000000', '1993-11-01T00:00:00.000000000',
#        '1993-12-01T00:00:00.000000000', '1994-01-01T00:00:00.000000000',
#        '1994-02-01T00:00:00.000000000', '1994-03-01T00:00:00.000000000',
#        '1994-04-01T00:00:00.000000000', '1994-05-01T00:00:00.000000000',
#        '1994-06-01T00:00:00.000000000', '1994-07-01T00:00:00.000000000',
#        '1994-08-01T00:00:00.000000000', '1994-09-01T00:00:00.000000000',
#        '1994-10-01T00:00:00.000000000', '1994-11-01T00:00:00.000000000',
#        '1994-12-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
uk_hp_index.head() #records from Aberdeenshire only start in 2004.
# Out:
#         Date     RegionName   AreaCode  AveragePrice  PriceIndex  \
# 0 2004-01-01  Aberdeenshire  S12000034   81693.66964   40.864214
# 1 2004-02-01  Aberdeenshire  S12000034   81678.76231   40.856757
# 2 2004-03-01  Aberdeenshire  S12000034   83525.09702   41.780317
# 3 2004-04-01  Aberdeenshire  S12000034   84333.67900   42.184780
# 4 2004-05-01  Aberdeenshire  S12000034   86379.95396   43.208353
#
#    PriceIndexSA  1mChange  12mChange  AveragePriceSA  SalesVolume  ...  \
# 0           NaN       NaN        NaN             NaN        388.0  ...
# 1           NaN -0.018248        NaN             NaN        326.0  ...
# 2           NaN  2.260483        NaN             NaN        453.0  ...
# 3           NaN  0.968071        NaN             NaN        571.0  ...
# 4           NaN  2.426403        NaN             NaN        502.0  ...
#
#    New12mChange  NewSalesVolume     OldPrice  OldPriceIndex  Old1mChange  \
# 0           NaN           103.0  81043.95084      40.883367          NaN
# 1           NaN           107.0  80965.29542      40.843688    -0.097053
# 2           NaN           140.0  82903.23948      41.821302     2.393549
# 3           NaN           180.0  84003.99161      42.376586     1.327755
# 4           NaN           167.0  86222.73484      43.495852     2.641235
#
#    Old12mChange  OldSalesVolume         Country     state         county
# 0           NaN           285.0  United Kingdom  Scotland  Aberdeenshire
# 1           NaN           219.0  United Kingdom  Scotland  Aberdeenshire
# 2           NaN           313.0  United Kingdom  Scotland  Aberdeenshire
# 3           NaN           391.0  United Kingdom  Scotland  Aberdeenshire
# 4           NaN           335.0  United Kingdom  Scotland  Aberdeenshire
#
# [5 rows x 57 columns]

# %% [markdown]
# > Creating Year and Month columns

# %%
uk_hp_index["Year"] = pd.DatetimeIndex(uk_hp_index["Date"]).year

# %%
uk_hp_index["Month"] = pd.DatetimeIndex(uk_hp_index["Date"]).month

# %% [markdown]
# ## Removing country, county, and state level entries

# %% [markdown]
# > Checking for records that contain values from the high level locations

# %%
shires = pd.unique(uk_hp_index[uk_hp_index["RegionName"].str.contains("shire", case=False)]["RegionName"])

# %%
# Dropping "shires"

uk_hp_index = uk_hp_index.loc[~uk_hp_index["RegionName"].isin(shires)]

# %% [markdown]
# > The dataset was viewed in excel, and the following regions were excluded.

# %%
excluded_regions = ['East of England', 'England', 'England and Wales','Scotland', 'Wales','Northern Ireland',
                    'United Kingdom','Great Britain','South West','South East','North West','North East',
                    'Greater Manchester', 'London','Merseyside', 'Tyne and Wear','Scottish Borders']

# %%
excluded_regions.extend(pd.unique(uk_hp_index[uk_hp_index["RegionName"].str.contains("midlands", case=False)]["RegionName"]))

# %%
uk_hp_index = uk_hp_index.loc[~uk_hp_index["RegionName"].isin(excluded_regions)]
uk_hp_index.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Imputing null counties

# %% [markdown]
# > There are 78 regions in which the county was not identified in the locations step. We will look over each of them in this step.

# %%
len(pd.unique(uk_hp_index[uk_hp_index["county"].isna()]["RegionName"]))
# Out:
# 78

# %%
# Counting the number for each state

sqldf("select count(distinct RegionName), state from uk_hp_index where county is null group by state")
# Out:
#    count(distinct RegionName)             state
# 0                          72           England
# 1                           3  Northern Ireland
# 2                           3          Scotland

# %%
# Looking at the regions in Scotland

sqldf("select distinct(RegionName) from uk_hp_index where state == 'Scotland' and county is null")
# Out:
#           RegionName
# 0   City of Aberdeen
# 1  City of Edinburgh
# 2           Waverley

# %% [markdown]
# > Waverley was discovered to be in Surrey, England

# %%
#Replacing the state and county

uk_hp_index.loc[uk_hp_index["RegionName"]=="Waverley", "county"] = "Surrey"
uk_hp_index.loc[uk_hp_index["RegionName"]=="Waverley", "state"] = "England"

# %%
#Imputing the remaining two counties

uk_hp_index.loc[uk_hp_index["RegionName"]=="City of Aberdeen", "county"] = "Aberdeenshire"
uk_hp_index.loc[uk_hp_index["RegionName"]=="City of Edinburgh", "county"] = "City of Edinburgh"

# %% [markdown]
# > Next we look at the regions in England. The regions' respective counties were identified using Google searches and imputed manually.

# %%
sqldf("select distinct county from uk_hp_index where state == 'England'")["county"].values
# Out:
# array(['West Sussex', 'Derbyshire', 'Nottinghamshire', 'Kent', 'Suffolk',
#        None, 'Essex', 'Hampshire', 'Bath and North East Somerset',
#        'Bedford', 'Leicestershire', 'Blackburn with Darwen', 'Blackpool',
#        'Lincolnshire', 'Bournemouth, Christchurch and Poole',
#        'Bracknell Forest', 'Norfolk', 'City of Milton Keynes',
#        'Brighton and Hove', 'Worcestershire', 'Hertfordshire',
#        'Lancashire', 'Cambridgeshire', 'Staffordshire', 'Gloucestershire',
#        'Oxfordshire', 'City of Bristol', 'Derby', 'Kingston upon Hull',
#        'City of Peterborough', 'Cornwall', 'County Durham', 'Cumberland',
#        'Darlington', 'Devon', 'Dorset', 'East Sussex', 'Surrey',
#        'Tyne and Wear', 'Halton', 'Hartlepool', 'Somerset',
#        'Isle of Wight', 'City of Leicester', 'Luton', 'Medway',
#        'Middlesbrough', 'North Somerset', 'Northumberland',
#        'Warwickshire', 'Redcar and Cleveland', 'Rutland',
#        'Stockton-on-Tees', 'Swindon', 'Telford and Wrekin', 'Thurrock',
#        'Torbay', 'Warrington', 'Cumbria', 'Windsor and Maidenhead',
#        'Wokingham', 'York'], dtype=object)

# %%
sqldf("select distinct RegionName from uk_hp_index where state == 'England' and county is null")["RegionName"].values
# Out:
# array(['Barking and Dagenham', 'Barnet', 'Barnsley', 'Bexley',
#        'Birmingham', 'Bolton', 'Bradford', 'Bromley', 'Broxtowe', 'Bury',
#        'Calderdale', 'Camden', 'City of London', 'City of Nottingham',
#        'City of Westminster', 'Coventry', 'Croydon', 'Doncaster',
#        'Dudley', 'Ealing', 'Enfield', 'Greenwich', 'Hackney',
#        'Hammersmith and Fulham', 'Haringey', 'Harrow', 'Hillingdon',
#        'Hounslow', 'Inner London', 'Islington', 'Kensington and Chelsea',
#        'Kingston upon Thames', 'Kirklees', 'Knowsley', 'Lambeth', 'Leeds',
#        'Lewisham', 'Liverpool', 'Manchester', 'Merton',
#        'Newcastle upon Tyne', 'Newham', 'North Tyneside', 'Oldham',
#        'Outer London', 'Portsmouth', 'Reading', 'Redbridge',
#        'Richmond upon Thames', 'Rochdale', 'Rotherham', 'Salford',
#        'Sandwell', 'Sefton', 'Sheffield', 'Slough', 'Solihull',
#        'Southampton', 'Southwark', 'St Helens', 'Stockport',
#        'Stoke-on-Trent', 'Sunderland', 'Sutton', 'Tameside', 'Trafford',
#        'Wakefield', 'Walsall', 'Wandsworth', 'Wigan', 'Wirral',
#        'Wolverhampton'], dtype=object)

# %% [markdown]
# >Northumberland and Staffordshire each had one unidentified region, and those were placed directly in the dataset

# %%
uk_hp_index.loc[uk_hp_index["RegionName"]=="Newcastle upon Tyne", "county"] = "Northumberland"
uk_hp_index.loc[uk_hp_index["RegionName"]=="Stoke-on-Trent", "county"] = "Staffordshire"

# %% [markdown]
# > The remaining counties had their regions aggregated and batch imputed

# %%
# Greater London Boroughs
ldn = ['Barking and Dagenham', 'Barnet', 'Bexley', 'Bromley', 'Camden', 'City of London','City of Westminster',
      'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney', 'Hammersmith and Fulham', 'Haringey', 'Harrow','Hillingdon',
      'Hounslow','Inner London', 'Islington', 'Kensington and Chelsea','Kingston upon Thames','Lambeth','Lewisham',
       'Merton','Newham', 'Outer London', 'Redbridge', 'Richmond upon Thames','Southwark', 'Sutton','Wandsworth']

# %%
# Yorkshire
yrk = ['Barnsley', 'Bradford', 'Calderdale', 'Doncaster', 'Kirklees', 'Leeds', 'Rotherham', 'Sheffield', 'Wakefield']

# %%
# Greater Manchester
manc = ['Bolton', 'Bury', 'Manchester', 'Oldham', 'Rochdale', 'Salford', 'Stockport', 'Tameside', 'Trafford', 'Wigan']

# %%
# Midlands
mid = ['Birmingham', 'Broxtowe', 'City of Nottingham', 'Coventry','Dudley', 'Sandwell', 'Solihull', 'Walsall',
       'Wolverhampton']

# %%
# Merseyside
mers = ['Knowsley','Liverpool','Sefton','St Helens','Wirral']

# %%
# Tyne and Wear
tyne = ['North Tyneside', 'Sunderland']

# %%
# Hampshire 
hamp = ['Portsmouth', 'Southampton']

# %%
# Berkshire
berk = ['Reading', 'Slough']

# %%
# Imputing
uk_hp_index.loc[uk_hp_index["RegionName"].isin(yrk), "county"] = "Yorkshire"
uk_hp_index.loc[uk_hp_index["RegionName"].isin(ldn), "county"] = "Greater London"
uk_hp_index.loc[uk_hp_index["RegionName"].isin(manc), "county"] = "Greater Manchester"
uk_hp_index.loc[uk_hp_index["RegionName"].isin(mid), "county"] = "Midlands"
uk_hp_index.loc[uk_hp_index["RegionName"].isin(mers), "county"] = "Merseyside"
uk_hp_index.loc[uk_hp_index["RegionName"].isin(tyne), "county"] = "Tyne and Wear"
uk_hp_index.loc[uk_hp_index["RegionName"].isin(hamp), "county"] = "Hampshire"
uk_hp_index.loc[uk_hp_index["RegionName"].isin(berk), "county"] = "Berkshire"

# %%
uk_hp_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105660 entries, 0 to 105659
# Data columns (total 59 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Date                    105660 non-null  datetime64[ns]
#  1   RegionName              105660 non-null  object
#  2   AreaCode                105660 non-null  object
#  3   AveragePrice            105660 non-null  float64
#  4   PriceIndex              105660 non-null  float64
#  5   PriceIndexSA            0 non-null       float64
#  6   1mChange                105320 non-null  float64
#  7   12mChange               101844 non-null  float64
#  8   AveragePriceSA          0 non-null       float64
#  9   SalesVolume             105018 non-null  float64
#  10  DetachedPrice           102900 non-null  float64
#  11  DetachedPriceIndex      102900 non-null  float64
#  12  Detached1mChange        102594 non-null  float64
#  13  Detached12mChange       99228 non-null   float64
#  14  SemiDetachedPrice       102900 non-null  float64
#  15  SemiDetachedPriceIndex  102900 non-null  float64
#  16  SemiDetached1mChange    102594 non-null  float64
#  17  SemiDetached12mChange   99228 non-null   float64
#  18  TerracedPrice           102927 non-null  float64
#  19  TerracedPriceIndex      102927 non-null  float64
#  20  Terraced1mChange        102621 non-null  float64
#  21  Terraced12mChange       99255 non-null   float64
#  22  FlatPrice               103240 non-null  float64
#  23  FlatPriceIndex          103240 non-null  float64
#  24  Flat1mChange            102933 non-null  float64
#  25  Flat12mChange           99556 non-null   float64
#  26  CashPrice               42160 non-null   float64
#  27  CashPriceIndex          42160 non-null   float64
#  28  Cash1mChange            41850 non-null   float64
#  29  Cash12mChange           38440 non-null   float64
#  30  CashSalesVolume         41538 non-null   float64
#  31  MortgagePrice           42160 non-null   float64
#  32  MortgagePriceIndex      42160 non-null   float64
#  33  Mortgage1mChange        41850 non-null   float64
#  34  Mortgage12mChange       38440 non-null   float64
#  35  MortgageSalesVolume     41539 non-null   float64
#  36  FTBPrice                42400 non-null   float64
#  37  FTBPriceIndex           42400 non-null   float64
#  38  FTB1mChange             42090 non-null   float64
#  39  FTB12mChange            38680 non-null   float64
#  40  FOOPrice                42160 non-null   float64
#  41  FOOPriceIndex           42160 non-null   float64
#  42  FOO1mChange             41850 non-null   float64
#  43  FOO12mChange            38440 non-null   float64
#  44  NewPrice                102583 non-null  float64
#  45  NewPriceIndex           102583 non-null  float64
#  46  New1mChange             102276 non-null  float64
#  47  New12mChange            98899 non-null   float64
#  48  NewSalesVolume          101018 non-null  float64
#  49  OldPrice                102620 non-null  float64
#  50  OldPriceIndex           102620 non-null  float64
#  51  Old1mChange             102313 non-null  float64
#  52  Old12mChange            98936 non-null   float64
#  53  OldSalesVolume          102620 non-null  float64
#  54  Country                 105660 non-null  object
#  55  state                   105660 non-null  object
#  56  county                  105000 non-null  object
#  57  Year                    105660 non-null  int64
#  58  Month                   105660 non-null  int64
# dtypes: datetime64[ns](1), float64(51), int64(2), object(5)
# memory usage: 47.6+ MB

# %% [markdown]
# ## Selecting dates for further analysis

# %% [markdown]
# > Defining the selected dates function

# %%
def select_dates(df, dates, start, end): #creating a function to filter selected dates from the dataset.
    
    start_date = pd.to_datetime(start)
    end_date = pd.to_datetime(end)
    
    final = df[(dates>=start_date)&(dates<=end_date)]
    final.reset_index(drop=True, inplace=True)
    
    return final

# %%
len(pd.unique(select_dates(df = uk_hp_index, dates = uk_hp_index["Date"], start = "1968-01-01", 
                           end = "2004-12-31")["RegionName"]))
#between 1968 and 2004, there are 394 regions.
# Out:
# 310

# %%
len(pd.unique(select_dates(df = uk_hp_index, dates = uk_hp_index["Date"], start = "2005-01-01", 
                           end = "2005-01-31")["RegionName"]))
#2005 has all 405 regions.
# Out:
# 321

# %%
selected_records = select_dates(df = uk_hp_index, dates = uk_hp_index["Date"], start = "2005-01-01", end = "2023-12-31")
#Selecting records from 2006-2023 to ensure homogeneous regions.
#Records from 2005 were selected to be used later in the analysis process.

# %%
selected_records.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70620 entries, 0 to 70619
# Data columns (total 59 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    70620 non-null  datetime64[ns]
#  1   RegionName              70620 non-null  object
#  2   AreaCode                70620 non-null  object
#  3   AveragePrice            70620 non-null  float64
#  4   PriceIndex              70620 non-null  float64
#  5   PriceIndexSA            0 non-null      float64
#  6   1mChange                70587 non-null  float64
#  7   12mChange               70488 non-null  float64
#  8   AveragePriceSA          0 non-null      float64
#  9   SalesVolume             69978 non-null  float64
#  10  DetachedPrice           67980 non-null  float64
#  11  DetachedPriceIndex      67980 non-null  float64
#  12  Detached1mChange        67980 non-null  float64
#  13  Detached12mChange       67980 non-null  float64
#  14  SemiDetachedPrice       67980 non-null  float64
#  15  SemiDetachedPriceIndex  67980 non-null  float64
#  16  SemiDetached1mChange    67980 non-null  float64
#  17  SemiDetached12mChange   67980 non-null  float64
#  18  TerracedPrice           68007 non-null  float64
#  19  TerracedPriceIndex      68007 non-null  float64
#  20  Terraced1mChange        68007 non-null  float64
#  21  Terraced12mChange       68007 non-null  float64
#  22  FlatPrice               68200 non-null  float64
#  23  FlatPriceIndex          68200 non-null  float64
#  24  Flat1mChange            68200 non-null  float64
#  25  Flat12mChange           68200 non-null  float64
#  26  CashPrice               42160 non-null  float64
#  27  CashPriceIndex          42160 non-null  float64
#  28  Cash1mChange            41850 non-null  float64
#  29  Cash12mChange           38440 non-null  float64
#  30  CashSalesVolume         41538 non-null  float64
#  31  MortgagePrice           42160 non-null  float64
#  32  MortgagePriceIndex      42160 non-null  float64
#  33  Mortgage1mChange        41850 non-null  float64
#  34  Mortgage12mChange       38440 non-null  float64
#  35  MortgageSalesVolume     41539 non-null  float64
#  36  FTBPrice                42400 non-null  float64
#  37  FTBPriceIndex           42400 non-null  float64
#  38  FTB1mChange             42090 non-null  float64
#  39  FTB12mChange            38680 non-null  float64
#  40  FOOPrice                42160 non-null  float64
#  41  FOOPriceIndex           42160 non-null  float64
#  42  FOO1mChange             41850 non-null  float64
#  43  FOO12mChange            38440 non-null  float64
#  44  NewPrice                67543 non-null  float64
#  45  NewPriceIndex           67543 non-null  float64
#  46  New1mChange             67543 non-null  float64
#  47  New12mChange            67543 non-null  float64
#  48  NewSalesVolume          65978 non-null  float64
#  49  OldPrice                67580 non-null  float64
#  50  OldPriceIndex           67580 non-null  float64
#  51  Old1mChange             67580 non-null  float64
#  52  Old12mChange            67580 non-null  float64
#  53  OldSalesVolume          67580 non-null  float64
#  54  Country                 70620 non-null  object
#  55  state                   70620 non-null  object
#  56  county                  69960 non-null  object
#  57  Year                    70620 non-null  int64
#  58  Month                   70620 non-null  int64
# dtypes: datetime64[ns](1), float64(51), int64(2), object(5)
# memory usage: 31.8+ MB

# %% [markdown]
# ## Selecting features for further analysis

# %% [markdown]
# > Property type columns will be used to train the model

# %%
# selected_records = selected_records[["Date", "RegionName","state","Country",""]]

# %%
detached = selected_records.columns[selected_records.columns.str.contains("detached", case=False)]
# list of features of detached and semi-detached properties.

# %%
semi_detached = detached[detached.str.contains("semi", case=False)]
# list of features of semi-detached properties.

# %%
detached = detached[~detached.str.contains("semi", case=False)]
detached
# list of features of detached properties.
# Out:
# Index(['DetachedPrice', 'DetachedPriceIndex', 'Detached1mChange',
#        'Detached12mChange'],
#       dtype='object')

# %%
terraced = selected_records.columns[selected_records.columns.str.contains("terraced", case=False)]
terraced
# list of features of terraced properties.
# Out:
# Index(['TerracedPrice', 'TerracedPriceIndex', 'Terraced1mChange',
#        'Terraced12mChange'],
#       dtype='object')

# %%
flat = selected_records.columns[selected_records.columns.str.contains("flat", case=False)]
flat
# list of features of flat properties.
# Out:
# Index(['FlatPrice', 'FlatPriceIndex', 'Flat1mChange', 'Flat12mChange'], dtype='object')

# %%
identifiers = pd.concat([selected_records.iloc[:,[0, 58, 57, 1, 56, 55]]], axis=1)
identifiers
# subsetting the identifying features (Date, Month, Year, Region, state)
# Out:
#             Date  Month  Year RegionName       county    state
# 0     2005-01-01      1  2005       Adur  West Sussex  England
# 1     2005-02-01      2  2005       Adur  West Sussex  England
# 2     2005-03-01      3  2005       Adur  West Sussex  England
# 3     2005-04-01      4  2005       Adur  West Sussex  England
# 4     2005-05-01      5  2005       Adur  West Sussex  England
# ...          ...    ...   ...        ...          ...      ...
# 70615 2022-12-01     12  2022       York         York  England
# 70616 2023-01-01      1  2023       York         York  England
# 70617 2023-02-01      2  2023       York         York  England
# 70618 2023-03-01      3  2023       York         York  England
# 70619 2023-04-01      4  2023       York         York  England
#
# [70620 rows x 6 columns]

# %% [markdown]
# ## Exploring different property types

# %%
# Creating a dataframe for the semidetached house type
semidetached_df = pd.concat([identifiers, selected_records[semi_detached]], axis=1)

# %%
semidetached_df.columns = semidetached_df.columns.str.replace('SemiDetached', '')
# removing the property type from the column name.
semidetached_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70620 entries, 0 to 70619
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        70620 non-null  datetime64[ns]
#  1   Month       70620 non-null  int64
#  2   Year        70620 non-null  int64
#  3   RegionName  70620 non-null  object
#  4   county      69960 non-null  object
#  5   state       70620 non-null  object
#  6   Price       67980 non-null  float64
#  7   PriceIndex  67980 non-null  float64
#  8   1mChange    67980 non-null  float64
#  9   12mChange   67980 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(3)
# memory usage: 5.4+ MB

# %%
semidetached_df.isna().sum()
#checking for NA values
# Out:
# Date             0
# Month            0
# Year             0
# RegionName       0
# county         660
# state            0
# Price         2640
# PriceIndex    2640
# 1mChange      2640
# 12mChange     2640
# dtype: int64

# %%
sqldf("select * from semidetached_df where Price is null").isna().sum()
#the index, month change, and year change are all null in the same places
# Out:
# Date             0
# Month            0
# Year             0
# RegionName       0
# county         660
# state            0
# Price         2640
# PriceIndex    2640
# 1mChange      2640
# 12mChange     2640
# dtype: int64

# %%
sqldf("select Distinct RegionName, state from semidetached_df where Price is null")
# Out:
#                              RegionName             state
# 0               Antrim and Newtownabbey  Northern Ireland
# 1                   Ards and North Down  Northern Ireland
# 2   Armagh City Banbridge and Craigavon  Northern Ireland
# 3                               Belfast  Northern Ireland
# 4              Causeway Coast and Glens  Northern Ireland
# 5                        City of London           England
# 6               Derry City and Strabane  Northern Ireland
# 7                   Fermanagh and Omagh  Northern Ireland
# 8               Lisburn and Castlereagh  Northern Ireland
# 9                            Mid Ulster  Northern Ireland
# 10                  Mid and East Antrim  Northern Ireland
# 11                Newry Mourne and Down  Northern Ireland

# %%
sqldf("select Distinct RegionName from semidetached_df where state = 'Northern Ireland'")
# Out:
#                              RegionName
# 0               Antrim and Newtownabbey
# 1                   Ards and North Down
# 2   Armagh City Banbridge and Craigavon
# 3                               Belfast
# 4              Causeway Coast and Glens
# 5               Derry City and Strabane
# 6                   Fermanagh and Omagh
# 7               Lisburn and Castlereagh
# 8                            Mid Ulster
# 9                   Mid and East Antrim
# 10                Newry Mourne and Down

# %%
sqldf("select count(*) from semidetached_df where state = 'Northern Ireland'")
# Out:
#    count(*)
# 0      2420

# %%
sqldf("select count(*) from semidetached_df where state = 'Northern Ireland' and Price is null")
# Out:
#    count(*)
# 0      2420

# %%
sqldf("select count(*) from semidetached_df where RegionName = 'City of London'")
# Out:
#    count(*)
# 0       220

# %%
sqldf("select count(*) as count_NA from semidetached_df where RegionName = 'City of London' and price is null")
# Out:
#    count_NA
# 0       220

# %% [markdown]
# > All entries in City of London and Northern Ireland are null for Semi-Detached houses. The next step is to check whether it's the same for other house types

# %%
# Detached

detached_df = pd.concat([identifiers, selected_records[detached]], axis=1)
detached_df.columns = detached_df.columns.str.replace('Detached', '')
sqldf("select Distinct RegionName, state from detached_df where Price is null")
# Out:
#                              RegionName             state
# 0               Antrim and Newtownabbey  Northern Ireland
# 1                   Ards and North Down  Northern Ireland
# 2   Armagh City Banbridge and Craigavon  Northern Ireland
# 3                               Belfast  Northern Ireland
# 4              Causeway Coast and Glens  Northern Ireland
# 5                        City of London           England
# 6               Derry City and Strabane  Northern Ireland
# 7                   Fermanagh and Omagh  Northern Ireland
# 8               Lisburn and Castlereagh  Northern Ireland
# 9                            Mid Ulster  Northern Ireland
# 10                  Mid and East Antrim  Northern Ireland
# 11                Newry Mourne and Down  Northern Ireland

# %%
detached_df.isna().sum()
# Out:
# Date             0
# Month            0
# Year             0
# RegionName       0
# county         660
# state            0
# Price         2640
# PriceIndex    2640
# 1mChange      2640
# 12mChange     2640
# dtype: int64

# %%
sqldf("select count(*) from detached_df where state = 'Northern Ireland' and Price is null")
# Out:
#    count(*)
# 0      2420

# %%
sqldf("select count(*) as count_NA from detached_df where RegionName = 'City of London' and price is null")
# Out:
#    count_NA
# 0       220

# %%
# Terraced

terraced_df = pd.concat([identifiers, selected_records[terraced]], axis=1)
terraced_df.columns = terraced_df.columns.str.replace('Terraced', '')
sqldf("select Distinct RegionName, state from terraced_df where Price is null")
# Out:
#                              RegionName             state
# 0               Antrim and Newtownabbey  Northern Ireland
# 1                   Ards and North Down  Northern Ireland
# 2   Armagh City Banbridge and Craigavon  Northern Ireland
# 3                               Belfast  Northern Ireland
# 4              Causeway Coast and Glens  Northern Ireland
# 5                        City of London           England
# 6               Derry City and Strabane  Northern Ireland
# 7                   Fermanagh and Omagh  Northern Ireland
# 8               Lisburn and Castlereagh  Northern Ireland
# 9                            Mid Ulster  Northern Ireland
# 10                  Mid and East Antrim  Northern Ireland
# 11                Newry Mourne and Down  Northern Ireland

# %%
terraced_df.isna().sum()
# Out:
# Date             0
# Month            0
# Year             0
# RegionName       0
# county         660
# state            0
# Price         2613
# PriceIndex    2613
# 1mChange      2613
# 12mChange     2613
# dtype: int64

# %%
sqldf("select count(*) from terraced_df where state = 'Northern Ireland' and Price is null")
# Out:
#    count(*)
# 0      2420

# %%
sqldf("select count(*) as count_NA from terraced_df where RegionName = 'City of London' and price is null")
# Out:
#    count_NA
# 0       193

# %%
sqldf("select count(*) from terraced_df where RegionName = 'City of London' and price is not null")
# Out:
#    count(*)
# 0        27

# %%
# Flat

flat_df = pd.concat([identifiers, selected_records[flat]], axis=1)
flat_df.columns = flat_df.columns.str.replace('Flat', '')
sqldf("select Distinct RegionName, state from flat_df where Price is null")
# Out:
#                              RegionName             state
# 0               Antrim and Newtownabbey  Northern Ireland
# 1                   Ards and North Down  Northern Ireland
# 2   Armagh City Banbridge and Craigavon  Northern Ireland
# 3                               Belfast  Northern Ireland
# 4              Causeway Coast and Glens  Northern Ireland
# 5               Derry City and Strabane  Northern Ireland
# 6                   Fermanagh and Omagh  Northern Ireland
# 7               Lisburn and Castlereagh  Northern Ireland
# 8                            Mid Ulster  Northern Ireland
# 9                   Mid and East Antrim  Northern Ireland
# 10                Newry Mourne and Down  Northern Ireland

# %%
flat_df.isna().sum()
# Out:
# Date             0
# Month            0
# Year             0
# RegionName       0
# county         660
# state            0
# Price         2420
# PriceIndex    2420
# 1mChange      2420
# 12mChange     2420
# dtype: int64

# %%
sqldf("select count(*) as count_NA from flat_df where state = 'Northern Ireland' and price is null")
# Out:
#    count_NA
# 0      2420

# %% [markdown]
# > The statement holds true for all property types except Flat, which has the values for the city of London. Records from Northern Ireland will be excluded  from the analysis, as well as records from City of London, as they are mostly absent.

# %% [markdown]
# ## Creating categories and lagged indices for the property types

# %% [markdown]
# > Creating a category column will transform the data from a wide format to a long format.

# %% [markdown]
# > Using lagged index columns can produce a stronger model, by incorporating the features used to calculate the index. This utilises nonlinear relationships between data, and also avoids discarding the data. Using the current index can lead to data leakage, as the index is derived from the price.

# %% [markdown]
# >The same can be said for 1-month and 12-month percentage changes, and these can also be used as lagged values.

# %%
# Semi-Detached

semidetached_df["PropertyType"] = "Semi-Detached"
#creating the property column

# %%
semidetached_df["LaggedIndex"] = semidetached_df["PriceIndex"].shift(1) #creating the lagged index column

# %%
semidetached_df[["Date","RegionName","LaggedIndex", "PriceIndex"]].head(24) #making sure the values correspond
# Out:
#          Date RegionName  LaggedIndex  PriceIndex
# 0  2005-01-01       Adur          NaN   72.025650
# 1  2005-02-01       Adur    72.025650   69.089726
# 2  2005-03-01       Adur    69.089726   70.192094
# 3  2005-04-01       Adur    70.192094   70.663027
# 4  2005-05-01       Adur    70.663027   72.000041
# 5  2005-06-01       Adur    72.000041   71.517048
# 6  2005-07-01       Adur    71.517048   70.641371
# 7  2005-08-01       Adur    70.641371   71.744684
# 8  2005-09-01       Adur    71.744684   72.403430
# 9  2005-10-01       Adur    72.403430   73.148106
# 10 2005-11-01       Adur    73.148106   71.712048
# 11 2005-12-01       Adur    71.712048   71.828221
# 12 2006-01-01       Adur    71.828221   71.243456
# 13 2006-02-01       Adur    71.243456   71.880790
# 14 2006-03-01       Adur    71.880790   71.869142
# 15 2006-04-01       Adur    71.869142   72.653979
# 16 2006-05-01       Adur    72.653979   73.793903
# 17 2006-06-01       Adur    73.793903   73.548170
# 18 2006-07-01       Adur    73.548170   75.854815
# 19 2006-08-01       Adur    75.854815   75.648079
# 20 2006-09-01       Adur    75.648079   78.133866
# 21 2006-10-01       Adur    78.133866   77.714919
# 22 2006-11-01       Adur    77.714919   78.412755
# 23 2006-12-01       Adur    78.412755   78.227714

# %%
semidetached_df[["Date","RegionName","LaggedIndex", "PriceIndex"]].tail(24) #making sure the values correspond
# Out:
#             Date RegionName  LaggedIndex  PriceIndex
# 70596 2021-05-01       York   133.503873  136.219886
# 70597 2021-06-01       York   136.219886  136.764258
# 70598 2021-07-01       York   136.764258  136.423833
# 70599 2021-08-01       York   136.423833  135.988140
# 70600 2021-09-01       York   135.988140  135.760647
# 70601 2021-10-01       York   135.760647  139.036744
# 70602 2021-11-01       York   139.036744  141.574610
# 70603 2021-12-01       York   141.574610  143.607417
# 70604 2022-01-01       York   143.607417  142.562875
# 70605 2022-02-01       York   142.562875  143.485458
# 70606 2022-03-01       York   143.485458  142.289725
# 70607 2022-04-01       York   142.289725  145.067080
# 70608 2022-05-01       York   145.067080  148.894160
# 70609 2022-06-01       York   148.894160  153.366032
# 70610 2022-07-01       York   153.366032  156.406814
# 70611 2022-08-01       York   156.406814  156.149580
# 70612 2022-09-01       York   156.149580  157.395245
# 70613 2022-10-01       York   157.395245  157.431242
# 70614 2022-11-01       York   157.431242  156.375032
# 70615 2022-12-01       York   156.375032  156.912477
# 70616 2023-01-01       York   156.912477  156.670394
# 70617 2023-02-01       York   156.670394  157.901661
# 70618 2023-03-01       York   157.901661  157.152773
# 70619 2023-04-01       York   157.152773  155.288851

# %%
# creating the lagged 1m and 12m change

semidetached_df["LaggedMonthChange"] = semidetached_df["1mChange"].shift(1)
semidetached_df["LaggedYearChange"] = semidetached_df["12mChange"].shift(12)

# %%
semidetached_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70620 entries, 0 to 70619
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               70620 non-null  datetime64[ns]
#  1   Month              70620 non-null  int64
#  2   Year               70620 non-null  int64
#  3   RegionName         70620 non-null  object
#  4   county             69960 non-null  object
#  5   state              70620 non-null  object
#  6   Price              67980 non-null  float64
#  7   PriceIndex         67980 non-null  float64
#  8   1mChange           67980 non-null  float64
#  9   12mChange          67980 non-null  float64
#  10  PropertyType       70620 non-null  object
#  11  LaggedIndex        67979 non-null  float64
#  12  LaggedMonthChange  67979 non-null  float64
#  13  LaggedYearChange   67968 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(2), object(4)
# memory usage: 7.5+ MB

# %%
semidetached_df.drop(columns=["PriceIndex","1mChange", "12mChange"], inplace=True)

# %%
# Detached

detached_df["PropertyType"] = "Detached"
detached_df["LaggedIndex"] = detached_df["PriceIndex"].shift(1)
detached_df["LaggedMonthChange"] = detached_df["1mChange"].shift(1)
detached_df["LaggedYearChange"] = detached_df["12mChange"].shift(12)
detached_df.drop(columns=["PriceIndex","1mChange", "12mChange"], inplace=True)
detached_df.head()
# Out:
#         Date  Month  Year RegionName       county    state        Price  \
# 0 2005-01-01      1  2005       Adur  West Sussex  England  271270.7029
# 1 2005-02-01      2  2005       Adur  West Sussex  England  259423.6415
# 2 2005-03-01      3  2005       Adur  West Sussex  England  263129.7082
# 3 2005-04-01      4  2005       Adur  West Sussex  England  263037.4922
# 4 2005-05-01      5  2005       Adur  West Sussex  England  268621.0494
#
#   PropertyType  LaggedIndex  LaggedMonthChange  LaggedYearChange
# 0     Detached          NaN                NaN               NaN
# 1     Detached    72.033817          -1.494210               NaN
# 2     Detached    68.887922          -4.367247               NaN
# 3     Detached    69.872039           1.428577               NaN
# 4     Detached    69.847552          -0.035046               NaN

# %%
# Terraced

terraced_df["PropertyType"] = "Terraced"
terraced_df["LaggedIndex"] = terraced_df["PriceIndex"].shift(1)
terraced_df["LaggedMonthChange"] = terraced_df["1mChange"].shift(1)
terraced_df["LaggedYearChange"] = terraced_df["12mChange"].shift(12)
terraced_df.drop(columns=["PriceIndex","1mChange", "12mChange"], inplace=True)
terraced_df.head()
# Out:
#         Date  Month  Year RegionName       county    state        Price  \
# 0 2005-01-01      1  2005       Adur  West Sussex  England  168151.0808
# 1 2005-02-01      2  2005       Adur  West Sussex  England  161262.9939
# 2 2005-03-01      3  2005       Adur  West Sussex  England  163686.8852
# 3 2005-04-01      4  2005       Adur  West Sussex  England  164991.4247
# 4 2005-05-01      5  2005       Adur  West Sussex  England  168582.6873
#
#   PropertyType  LaggedIndex  LaggedMonthChange  LaggedYearChange
# 0     Terraced          NaN                NaN               NaN
# 1     Terraced    70.256619          -1.361034               NaN
# 2     Terraced    67.378649          -4.096368               NaN
# 3     Terraced    68.391396           1.503067               NaN
# 4     Terraced    68.936456           0.796973               NaN

# %%
# Flat

flat_df["PropertyType"] = "Flat"
flat_df["LaggedIndex"] = flat_df["PriceIndex"].shift(1)
flat_df["LaggedMonthChange"] = flat_df["1mChange"].shift(1)
flat_df["LaggedYearChange"] = flat_df["12mChange"].shift(12)
flat_df.drop(columns=["PriceIndex","1mChange", "12mChange"], inplace=True)
flat_df.head()
# Out:
#         Date  Month  Year RegionName       county    state        Price  \
# 0 2005-01-01      1  2005       Adur  West Sussex  England  129135.9120
# 1 2005-02-01      2  2005       Adur  West Sussex  England  123532.0211
# 2 2005-03-01      3  2005       Adur  West Sussex  England  125076.0910
# 3 2005-04-01      4  2005       Adur  West Sussex  England  125924.5936
# 4 2005-05-01      5  2005       Adur  West Sussex  England  128625.0053
#
#   PropertyType  LaggedIndex  LaggedMonthChange  LaggedYearChange
# 0         Flat          NaN                NaN               NaN
# 1         Flat    80.581132          -1.605792               NaN
# 2         Flat    77.084290          -4.339529               NaN
# 3         Flat    78.047794           1.249935               NaN
# 4         Flat    78.577262           0.678389               NaN

# %% [markdown]
# ## Joining the dataframes together in long format

# %% [markdown]
# > Here, the four dataframes are concatenated row-wise, and the records from 2005 are removed.

# %% [markdown]
# > The records from Northern Ireland and the London sub-regions are also removed.

# %%
hp_index_long = pd.concat([semidetached_df, detached_df, terraced_df, flat_df],axis=0) #row-wise concatenation
hp_index_long.reset_index(drop=True, inplace=True)

# %%
# capitalising the state and county columns, renaming price as AvgPrice.

hp_index_long.columns = hp_index_long.columns.str.replace('county','County')
hp_index_long.columns = hp_index_long.columns.str.replace('state','State')
hp_index_long.columns = hp_index_long.columns.str.replace('Price','AvgPrice')

# %%
hp_index_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282480 entries, 0 to 282479
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date               282480 non-null  datetime64[ns]
#  1   Month              282480 non-null  int64
#  2   Year               282480 non-null  int64
#  3   RegionName         282480 non-null  object
#  4   County             279840 non-null  object
#  5   State              282480 non-null  object
#  6   AvgPrice           272167 non-null  float64
#  7   PropertyType       282480 non-null  object
#  8   LaggedIndex        272163 non-null  float64
#  9   LaggedMonthChange  272163 non-null  float64
#  10  LaggedYearChange   272119 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(4)
# memory usage: 23.7+ MB

# %%
hp_index_long = hp_index_long.sort_values(by=["RegionName","PropertyType","Date"])

# %%
hp_index_long = select_dates(df=hp_index_long, dates=hp_index_long["Date"], start="2006-01-01", end="2023-12-31")

# %% [markdown]
# ### Removing Northern Ireland and the City of London

# %%
# Removing Northern Ireland records

hp_index_long = hp_index_long[~(hp_index_long["State"]=="Northern Ireland")]

# %%
hp_index_final = hp_index_long[~(hp_index_long["RegionName"]=="City of London")]

# %% [markdown]
# > Dropping the date column

# %%
hp_index_final = hp_index_final.drop(columns=["Date"])

# %%
hp_index_final.isna().sum()
# Out:
# Month                0
# Year                 0
# RegionName           0
# County               0
# State                0
# AvgPrice             0
# PropertyType         0
# LaggedIndex          0
# LaggedMonthChange    0
# LaggedYearChange     0
# dtype: int64

# %%
hp_index_final.to_sql(name="modified_hp_data", con=engine, if_exists="replace",index=None)
# Out:
# 257088

# %%
# uk_hp_index["Year"] = pd.DatetimeIndex(uk_hp_index["Date"]).year

# %%
# len(pd.unique(uk_hp_index["Year"]))

# %%
# uk_hp_index[(uk_hp_index["Year"]<=2022) & (uk_hp_index["Year"]>=2012)]

# %%
# uk_hp_index[uk_hp_index["Year"]==2023]

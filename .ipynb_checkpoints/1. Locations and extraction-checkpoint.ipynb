# %% [markdown]
# # Importing libraries & data

# %%
import pandas as pd
import numpy as np
from pandasql import sqldf
from geopy.geocoders import Nominatim
from MySQLConnect import mysql_engine

# %%
uk_hpi = pd.read_csv("http://publicdata.landregistry.gov.uk/market-trend-data/house-price-index-data/UK-HPI-full-file-2023-04.csv?utm_medium=GOV.UK&utm_source=datadownload&utm_campaign=full_fil&utm_term=9.30_21_06_23")

# %%
uk_hpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136125 entries, 0 to 136124
# Data columns (total 54 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Date                    136125 non-null  object
#  1   RegionName              136125 non-null  object
#  2   AreaCode                136125 non-null  object
#  3   AveragePrice            136125 non-null  float64
#  4   Index                   136125 non-null  float64
#  5   IndexSA                 4764 non-null    float64
#  6   1m%Change               135702 non-null  float64
#  7   12m%Change              131325 non-null  float64
#  8   AveragePriceSA          4764 non-null    float64
#  9   SalesVolume             131658 non-null  float64
#  10  DetachedPrice           129708 non-null  float64
#  11  DetachedIndex           129708 non-null  float64
#  12  Detached1m%Change       129319 non-null  float64
#  13  Detached12m%Change      125064 non-null  float64
#  14  SemiDetachedPrice       129708 non-null  float64
#  15  SemiDetachedIndex       129708 non-null  float64
#  16  SemiDetached1m%Change   129319 non-null  float64
#  17  SemiDetached12m%Change  125064 non-null  float64
#  18  TerracedPrice           129735 non-null  float64
#  19  TerracedIndex           129735 non-null  float64
#  20  Terraced1m%Change       129346 non-null  float64
#  21  Terraced12m%Change      125091 non-null  float64
#  22  FlatPrice               130048 non-null  float64
#  23  FlatIndex               130048 non-null  float64
#  24  Flat1m%Change           129658 non-null  float64
#  25  Flat12m%Change          125392 non-null  float64
#  26  CashPrice               53312 non-null   float64
#  27  CashIndex               53312 non-null   float64
#  28  Cash1m%Change           52922 non-null   float64
#  29  Cash12m%Change          48632 non-null   float64
#  30  CashSalesVolume         52526 non-null   float64
#  31  MortgagePrice           53312 non-null   float64
#  32  MortgageIndex           53312 non-null   float64
#  33  Mortgage1m%Change       52922 non-null   float64
#  34  Mortgage12m%Change      48632 non-null   float64
#  35  MortgageSalesVolume     52527 non-null   float64
#  36  FTBPrice                53708 non-null   float64
#  37  FTBIndex                53708 non-null   float64
#  38  FTB1m%Change            53318 non-null   float64
#  39  FTB12m%Change           49028 non-null   float64
#  40  FOOPrice                53312 non-null   float64
#  41  FOOIndex                53312 non-null   float64
#  42  FOO1m%Change            52922 non-null   float64
#  43  FOO12m%Change           48632 non-null   float64
#  44  NewPrice                129019 non-null  float64
#  45  NewIndex                129223 non-null  float64
#  46  New1m%Change            128833 non-null  float64
#  47  New12m%Change           124567 non-null  float64
#  48  NewSalesVolume          127557 non-null  float64
#  49  OldPrice                129260 non-null  float64
#  50  OldIndex                129260 non-null  float64
#  51  Old1m%Change            128870 non-null  float64
#  52  Old12m%Change           124604 non-null  float64
#  53  OldSalesVolume          129248 non-null  float64
# dtypes: float64(51), object(3)
# memory usage: 56.1+ MB

# %% [markdown]
# # Extracting region data

# %%
uk_hpi["Country"]= "United Kingdom" #creating a "country" column and filling every entry with "United Kingdom"

# %%
uk_hpi["Region"]=uk_hpi["RegionName"] + ", " + uk_hpi["Country"] #combining region name and country for accurate geocoding

# %%
uk_hpi.head()
# Out:
#          Date     RegionName   AreaCode  AveragePrice      Index  IndexSA  \
# 0  01/01/2004  Aberdeenshire  S12000034   81693.66964  40.864214      NaN
# 1  01/02/2004  Aberdeenshire  S12000034   81678.76231  40.856757      NaN
# 2  01/03/2004  Aberdeenshire  S12000034   83525.09702  41.780317      NaN
# 3  01/04/2004  Aberdeenshire  S12000034   84333.67900  42.184780      NaN
# 4  01/05/2004  Aberdeenshire  S12000034   86379.95396  43.208353      NaN
#
#    1m%Change  12m%Change  AveragePriceSA  SalesVolume  ...  New1m%Change  \
# 0        NaN         NaN             NaN        388.0  ...           NaN
# 1  -0.018248         NaN             NaN        326.0  ...      0.192576
# 2   2.260483         NaN             NaN        453.0  ...      1.907838
# 3   0.968071         NaN             NaN        571.0  ...      0.025432
# 4   2.426403         NaN             NaN        502.0  ...      1.848208
#
#    New12m%Change  NewSalesVolume     OldPrice   OldIndex  Old1m%Change  \
# 0            NaN           103.0  81043.95084  40.883367           NaN
# 1            NaN           107.0  80965.29542  40.843688     -0.097053
# 2            NaN           140.0  82903.23948  41.821302      2.393549
# 3            NaN           180.0  84003.99161  42.376586      1.327755
# 4            NaN           167.0  86222.73484  43.495852      2.641235
#
#    Old12m%Change  OldSalesVolume         Country  \
# 0            NaN           285.0  United Kingdom
# 1            NaN           219.0  United Kingdom
# 2            NaN           313.0  United Kingdom
# 3            NaN           391.0  United Kingdom
# 4            NaN           335.0  United Kingdom
#
#                           Region
# 0  Aberdeenshire, United Kingdom
# 1  Aberdeenshire, United Kingdom
# 2  Aberdeenshire, United Kingdom
# 3  Aberdeenshire, United Kingdom
# 4  Aberdeenshire, United Kingdom
#
# [5 rows x 56 columns]

# %%
# uk_hpi.drop(["RegionName","Country"], axis=1, inplace=True) #dropping region name and country columns.

# %%
len(uk_hpi["Region"].unique())
# Out:
# 405

# %%
regions = uk_hpi[["Region"]].drop_duplicates(keep="last") #creating a new dataframe with only unique region values.
regions.reset_index(inplace=True, drop=True)
regions
# Out:
#                                        Region
# 0               Aberdeenshire, United Kingdom
# 1                        Adur, United Kingdom
# 2                Amber Valley, United Kingdom
# 3                       Angus, United Kingdom
# 4     Antrim and Newtownabbey, United Kingdom
# ..                                        ...
# 400                  Wychavon, United Kingdom
# 401                      Wyre, United Kingdom
# 402               Wyre Forest, United Kingdom
# 403                      York, United Kingdom
# 404  Yorkshire and The Humber, United Kingdom
#
# [405 rows x 1 columns]

# %%
regions.duplicated().sum()
# Out:
# 0

# %%
regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Region  405 non-null    object
# dtypes: object(1)
# memory usage: 3.3+ KB

# %%
geolocator = Nominatim(user_agent="uk_regions_list") #creating a geocoder instance for future use.

coordinates = [] #creating an empty list to store coordinates.

# %%
for region in regions["Region"]:
    location = geolocator.geocode(region)
    if location is not None:
        coordinates.append((region, location.latitude, location.longitude))
#geocoding the "Region" column using a  to retrieve coordinates, and storing the coordinates and region names in empty list.

# %%
# regions[regions["Region"].str.contains("angus", case=False)]

# %%
coordinates
# Out:
# [('Aberdeenshire, United Kingdom', 57.166667, -2.666667),
#  ('Adur, United Kingdom', 50.8453169, -0.2939886608407643),
#  ('Amber Valley, United Kingdom', 53.029038400000005, -1.4625031096700565),
#  ('Angus, United Kingdom', 56.666667, -2.916667),
#  ('Antrim and Newtownabbey, United Kingdom', 54.6951611, -5.946965601134577),
#  ('Ards and North Down, United Kingdom', 54.64896425, -5.562785215049392),
#  ('Argyll and Bute, United Kingdom', 56.4603494, -5.8618419478791015),
#  ('Arun, United Kingdom', 50.8312375, -0.5667058666407475),
#  ('Ashfield, United Kingdom', 53.089773750000006, -1.2518767461557148),
#  ('Ashford, United Kingdom', 51.148555, 0.8722566),
#  ('Babergh, United Kingdom', 52.06297535, 0.9122241568513769),
#  ('Barking and Dagenham, United Kingdom', 51.5540907, 0.15048888801039415),
#  ('Barnet, United Kingdom', 51.65309, -0.2002261),
#  ('Barnsley, United Kingdom', 53.5527719, -1.4827755),
#  ('Basildon, United Kingdom', 51.5754602, 0.4757363),
#  ('Basingstoke and Deane, United Kingdom', 51.2587797, -1.221107318149007),
#  ('Bassetlaw, United Kingdom', 53.34945205, -0.9616604011939824),
#  ('Bath and North East Somerset, United Kingdom',
#   51.35632375,
#   -2.486661424502094),
#  ('Bedford, United Kingdom', 52.1363806, -0.4675041),
#  ('Belfast, United Kingdom', 54.596391, -5.9301829),
#  ('Bexley, United Kingdom', 51.4416793, 0.150488),
#  ('Birmingham, United Kingdom', 52.4796992, -1.9026911),
#  ('Blaby, United Kingdom', 52.5731976, -1.1646389),
#  ('Blackburn with Darwen, United Kingdom',
#   53.699176949999995,
#   -2.4709000953138327),
#  ('Blackpool, United Kingdom', 53.8179442, -3.0509812),
#  ('Blaenau Gwent, United Kingdom', 51.75338175, -3.184855509462492),
#  ('Bolsover, United Kingdom', 53.228666, -1.2912756),
#  ('Bolton, United Kingdom', 53.5782863, -2.4300367),
#  ('Boston, United Kingdom', 52.9770408, -0.0239836),
#  ('Bournemouth Christchurch and Poole, United Kingdom',
#   50.745545899999996,
#   -1.8481780552846188),
#  ('Bracknell Forest, United Kingdom', 51.4002688, -0.7417888011413043),
#  ('Bradford, United Kingdom', 53.7944229, -1.7519186),
#  ('Braintree, United Kingdom', 51.8780637, 0.5537161),
#  ('Breckland, United Kingdom', 52.5903063, 0.7590363095765305),
#  ('Brent, United Kingdom', 52.0184864, -0.7235177),
#  ('Brentwood, United Kingdom', 51.6201654, 0.3018662),
#  ('Bridgend, United Kingdom', 51.5049859, -3.5756674),
#  ('Brighton and Hove, United Kingdom', 50.8453169, -0.14974689789029522),
#  ('Broadland, United Kingdom', 52.6928977, 1.2564875194162244),
#  ('Bromley, United Kingdom', 51.4028046, 0.0148142),
#  ('Bromsgrove, United Kingdom', 52.3390519, -2.0532017992446177),
#  ('Broxbourne, United Kingdom', 51.7465723, -0.0190782),
#  ('Broxtowe, United Kingdom', 52.9782566, -1.2170642),
#  ('Buckinghamshire, United Kingdom', 51.7834994, -0.8946440535649794),
#  ('Burnley, United Kingdom', 53.7907262, -2.2439196),
#  ('Bury, United Kingdom', 53.5927543, -2.2972827),
#  ('Caerphilly, United Kingdom', 51.6723809, -3.178393772876317),
#  ('Calderdale, United Kingdom', 53.720474800000005, -1.9622886329676708),
#  ('Cambridge, United Kingdom', 52.2055314, 0.1186637),
#  ('Cambridgeshire, United Kingdom', 52.333333, 0.083333),
#  ('Camden, United Kingdom', 51.54279655, -0.16248031357798964),
#  ('Cannock Chase, United Kingdom', 52.7069197, -1.9784347546729857),
#  ('Canterbury, United Kingdom', 51.2800275, 1.0802533),
#  ('Cardiff, United Kingdom', 51.4816546, -3.1791934),
#  ('Carmarthenshire, United Kingdom', 51.893669849999995, -4.217282721429928),
#  ('Castle Point, United Kingdom', 51.54450755, 0.5840084067307691),
#  ('Causeway Coast and Glens, United Kingdom',
#   55.130595400000004,
#   -6.327745858099967),
#  ('Central Bedfordshire, United Kingdom', 51.99803275, -0.47915142854055964),
#  ('Ceredigion, United Kingdom', 52.2945764, -3.9527809990291427),
#  ('Charnwood, United Kingdom', 52.7392639, -1.1370832780406597),
#  ('Chelmsford, United Kingdom', 51.7345329, 0.4730532),
#  ('Cheltenham, United Kingdom', 51.8995685, -2.0711559),
#  ('Cherwell, United Kingdom', 51.974716900000004, -1.2262941038785593),
#  ('Cheshire East, United Kingdom', 53.1673422, -2.2928802778613573),
#  ('Cheshire West and Chester, United Kingdom',
#   53.16379785,
#   -2.7285361135416943),
#  ('Chesterfield, United Kingdom', 53.2352134, -1.4264097),
#  ('Chichester, United Kingdom', 50.84467705, -0.7831144316193243),
#  ('Chorley, United Kingdom', 53.6531915, -2.6294313),
#  ('City of Aberdeen, United Kingdom', 57.14796285, -2.1057536956155145),
#  ('City of Bristol, United Kingdom', 51.4430523, -2.581638861285822),
#  ('City of Derby, United Kingdom', 52.87564810000001, -1.4900753478503028),
#  ('City of Dundee, United Kingdom', 56.473845999999995, -2.96641895351409),
#  ('City of Edinburgh, United Kingdom', 55.9533456, -3.1883749),
#  ('City of Glasgow, United Kingdom', 55.85551155, -4.226230657258229),
#  ('City of Kingston upon Hull, United Kingdom',
#   53.76238625,
#   -0.3301213755327681),
#  ('City of London, United Kingdom', 51.5156177, -0.0919983),
#  ('City of Nottingham, United Kingdom', 52.9534193, -1.1496461),
#  ('City of Peterborough, United Kingdom', 52.5906848, -0.263083565081749),
#  ('City of Plymouth, United Kingdom', 51.61770535, -3.9461904798723895),
#  ('City of Westminster, United Kingdom', 51.4973206, -0.137149),
#  ('Clackmannanshire, United Kingdom', 56.166395, -3.7513968),
#  ('Colchester, United Kingdom', 51.8896903, 0.8994651),
#  ('Conwy, United Kingdom', 53.1460931, -3.759920155777771),
#  ('Cornwall, United Kingdom', 50.416667, -4.75),
#  ('Cotswold, United Kingdom', 51.84516805, -1.891330800141246),
#  ('County Durham, United Kingdom', 54.666667, -1.75),
#  ('Coventry, United Kingdom', 52.4081812, -1.510477),
#  ('Crawley, United Kingdom', 51.1103444, -0.1801094),
#  ('Croydon, United Kingdom', 51.3713049, -0.101957),
#  ('Cumberland, United Kingdom', 54.67842505, -3.304001955591123),
#  ('Dacorum, United Kingdom', 51.768954050000005, -0.5515510187562057),
#  ('Darlington, United Kingdom', 54.5242081, -1.5555812),
#  ('Dartford, United Kingdom', 51.4443059, 0.21807),
#  ('Denbighshire, United Kingdom', 53.1097895, -3.367128402684635),
#  ('Derbyshire, United Kingdom', 53.1185033, -1.5566179305872214),
#  ('Derbyshire Dales, United Kingdom', 53.1302876, -1.6561732789685428),
#  ('Derry City and Strabane, United Kingdom', 54.8351485, -7.457994790640386),
#  ('Devon, United Kingdom', 50.724140500000004, -3.6607788161410735),
#  ('Doncaster, United Kingdom', 53.5227681, -1.1335312),
#  ('Dorset, United Kingdom', 50.79683685, -2.34473226124306),
#  ('Dover, United Kingdom', 51.1251275, 1.3134228),
#  ('Dudley, United Kingdom', 52.5110832, -2.0816813),
#  ('Dumfries and Galloway, United Kingdom', 55.083333, -3.833333),
#  ('Ealing, United Kingdom', 51.5126553, -0.3051952),
#  ('East Ayrshire, United Kingdom', 55.5, -4.25),
#  ('East Cambridgeshire, United Kingdom', 52.33498865, 0.26289392438863995),
#  ('East Devon, United Kingdom', 50.7568771, -3.221564289113528),
#  ('East Dunbartonshire, United Kingdom', 55.933333, -4.2),
#  ('East Hampshire, United Kingdom', 51.07788895, -0.9439075864537129),
#  ('East Hertfordshire, United Kingdom', 51.86567885, 0.012485012653673036),
#  ('East Lindsey, United Kingdom', 53.2680103, 0.012775773043408906),
#  ('East Lothian, United Kingdom', 55.915797, -2.7511952),
#  ('East Midlands, United Kingdom', 52.7965611, -0.6717947564067988),
#  ('East Renfrewshire, United Kingdom', 55.749479300000004, -4.36065924945091),
#  ('East Riding of Yorkshire, United Kingdom', 53.9112323, -0.5813105),
#  ('East Staffordshire, United Kingdom', 52.8878642, -1.9030802448726154),
#  ('East Suffolk, United Kingdom', 52.241001350000005, 1.4582089310327726),
#  ('East Sussex, United Kingdom', 50.9404266, 0.3699977891068864),
#  ('East of England, United Kingdom', 52.2199774, 0.4875777469166293),
#  ('Eastbourne, United Kingdom', 50.7664372, 0.2781546),
#  ('Eastleigh, United Kingdom', 50.9202337, -1.2992656195130934),
#  ('Elmbridge, United Kingdom', 52.308409, -2.1474369),
#  ('Enfield, United Kingdom', 51.6520851, -0.0810175),
#  ('England, United Kingdom', 52.5310214, -1.2649062),
#  ('England and Wales, United Kingdom',
#   51.516368299999996,
#   -0.08815569752751584),
#  ('Epping Forest, United Kingdom', 51.6676884, 0.054801129257444646),
#  ('Epsom and Ewell, United Kingdom', 51.3363098, -0.26738169267465284),
#  ('Erewash, United Kingdom', 52.93800485, -1.3513172392396116),
#  ('Essex, United Kingdom', 51.77046785, 0.46466977412300386),
#  ('Exeter, United Kingdom', 50.7255794, -3.5269497),
#  ('Falkirk, United Kingdom', 55.9991959, -3.784376),
#  ('Fareham, United Kingdom', 50.8526637, -1.1783134),
#  ('Fenland, United Kingdom', 52.56284005, 0.010157722129947797),
#  ('Fermanagh and Omagh, United Kingdom', 54.4413243, -7.7567616226758105),
#  ('Fife, United Kingdom', 56.3333331, -3.0000001),
#  ('Flintshire, United Kingdom', 53.216509599999995, -3.1402189049730413),
#  ('Folkestone and Hythe, United Kingdom', 51.05774845, 1.0060720698429628),
#  ('Forest of Dean, United Kingdom', 51.7996179, -2.5305841628747032),
#  ('Fylde, United Kingdom', 53.79336215, -2.89426008005),
#  ('Gateshead, United Kingdom', 54.9625789, -1.6019294),
#  ('Gedling, United Kingdom', 53.02605385, -1.1071169188526024),
#  ('Gloucester, United Kingdom', 51.8653705, -2.2458192),
#  ('Gloucestershire, United Kingdom', 51.8333313, -2.1666674),
#  ('Gosport, United Kingdom', 50.7952074, -1.1210853),
#  ('Gravesham, United Kingdom', 51.39723695, 0.3961725871463415),
#  ('Great Britain, United Kingdom', 54.3151594, -1.9181532111487878),
#  ('Great Yarmouth, United Kingdom', 52.6071742, 1.7314845),
#  ('Greater Manchester, United Kingdom', 53.50652485, -2.3374401422576687),
#  ('Greenwich, United Kingdom', 51.4820845, -0.0045417),
#  ('Guildford, United Kingdom', 51.2356068, -0.5732063),
#  ('Gwynedd, United Kingdom', 52.9089585, -3.8335244282124785),
#  ('Hackney, United Kingdom', 51.5432402, -0.0493621),
#  ('Halton, United Kingdom', 53.35385255, -2.7427828785393507),
#  ('Hammersmith and Fulham, United Kingdom',
#   51.498314199999996,
#   -0.22787818358222445),
#  ('Hampshire, United Kingdom', 51.04483545, -1.2434093597173146),
#  ('Harborough, United Kingdom', 52.538568850000004, -0.9200444888910031),
#  ('Haringey, United Kingdom', 51.587929849999995, -0.10541771297992009),
#  ('Harlow, United Kingdom', 51.7676194, 0.0974893),
#  ('Harrow, United Kingdom', 51.596827149999996, -0.3373046180437286),
#  ('Hart, United Kingdom', 51.2761671, -0.8927989805623809),
#  ('Hartlepool, United Kingdom', 54.6857276, -1.2093696),
#  ('Hastings, United Kingdom', 50.8553888, 0.5824703),
#  ('Havant, United Kingdom', 50.8334197, -0.9826589433165432),
#  ('Havering, United Kingdom', 51.0358628, -2.8417544),
#  ('Herefordshire, United Kingdom', 52.083333, -2.75),
#  ('Hertfordshire, United Kingdom', 51.840052299999996, -0.09785519224523963),
#  ('Hertsmere, United Kingdom', 51.68082975, -0.2681113103109687),
#  ('High Peak, United Kingdom', 53.3675462, -1.8528746491564894),
#  ('Highland, United Kingdom', 57.5066357, -5.0038367),
#  ('Hillingdon, United Kingdom', 51.542519299999995, -0.44833493117949663),
#  ('Hinckley and Bosworth, United Kingdom', 52.608409, -1.4171909963481428),
#  ('Horsham, United Kingdom', 51.0630273, -0.3295028),
#  ('Hounslow, United Kingdom', 51.4686132, -0.3613471),
#  ('Huntingdonshire, United Kingdom', 52.37104395, -0.22357789271655937),
#  ('Hyndburn, United Kingdom', 53.7607317, -2.39005491388217),
#  ('Inner London, United Kingdom', 51.5128303, -0.1100526),
#  ('Inverclyde, United Kingdom', 55.9, -4.75),
#  ('Ipswich, United Kingdom', 52.0579324, 1.1528095),
#  ('Isle of Anglesey, United Kingdom', 53.27816025, -4.347871127822403),
#  ('Isle of Wight, United Kingdom', 50.67108245, -1.3328042802764226),
#  ('Islington, United Kingdom', 51.5384287, -0.0999051),
#  ('Kensington and Chelsea, United Kingdom', 51.50379515, -0.20078938323179596),
#  ('Kent, United Kingdom', 51.20707485, 0.7210361813401444),
#  ("King's Lynn and West Norfolk , United Kingdom",
#   52.71316265,
#   0.4348749234835659),
#  ('Kingston upon Thames, United Kingdom', 51.4096275, -0.3062621),
#  ('Kirklees, United Kingdom', 53.64226345, -1.7809432689150708),
#  ('Knowsley, United Kingdom', 53.4552358, -2.8546852),
#  ('Lambeth, United Kingdom', 51.4952111, -0.1163354),
#  ('Lancashire, United Kingdom', 53.8611703, -2.5650887919475496),
#  ('Lancaster, United Kingdom', 54.0484068, -2.7990345),
#  ('Leeds, United Kingdom', 53.7974185, -1.5437941),
#  ('Leicester, United Kingdom', 52.6362, -1.1331969),
#  ('Leicestershire, United Kingdom', 52.68491375, -1.1847653085946246),
#  ('Lewes, United Kingdom', 50.8746139, 0.005115324110936268),
#  ('Lewisham, United Kingdom', 51.4624292, -0.0101787),
#  ('Lichfield, United Kingdom', 52.68064, -1.8243991722405983),
#  ('Lincoln, United Kingdom', 53.2293545, -0.5404819),
#  ('Lincolnshire, United Kingdom', 53.1823034, -0.2031208542548153),
#  ('Liverpool, United Kingdom', 53.4071991, -2.99168),
#  ('London, United Kingdom', 51.5073359, -0.12765),
#  ('Luton, United Kingdom', 51.8784385, -0.4152837),
#  ('Maidstone, United Kingdom', 51.2748258, 0.5231646),
#  ('Maldon, United Kingdom', 51.7155563, 0.6843547574257541),
#  ('Malvern Hills, United Kingdom', 52.1675333, -2.3311602038846546),
#  ('Manchester, United Kingdom', 53.4794892, -2.2451148),
#  ('Mansfield, United Kingdom', 53.1443785, -1.1964165),
#  ('Medway, United Kingdom', 51.4157386, 0.5687308512408333),
#  ('Melton, United Kingdom', 52.8117106, -0.8592867292244459),
#  ('Merseyside, United Kingdom', 53.4953602, -2.973937960086006),
#  ('Merthyr Tydfil, United Kingdom', 51.7455659, -3.3786082),
#  ('Merton, United Kingdom', 51.41086985, -0.18809708858824303),
#  ('Mid Devon, United Kingdom', 50.86839225, -3.5996999898540123),
#  ('Mid Suffolk, United Kingdom', 52.23476185, 1.0451342631685334),
#  ('Mid Sussex, United Kingdom', 51.0053398, -0.1273113444043321),
#  ('Mid Ulster, United Kingdom', 54.13942805, -6.066426201835801),
#  ('Middlesbrough, United Kingdom', 54.5760419, -1.2344047),
#  ('Midlothian, United Kingdom', 55.833333, -3.083333),
#  ('Milton Keynes, United Kingdom', 52.0406502, -0.7594092),
#  ('Mole Valley, United Kingdom', 51.220094450000005, -0.33475519270708765),
#  ('Monmouthshire, United Kingdom', 51.7501058, -2.8333331),
#  ('Moray, United Kingdom', 57.416667, -3.25),
#  ('Na h-Eileanan Siar, United Kingdom', 57.666667, -7.166667),
#  ('Neath Port Talbot, United Kingdom', 51.66895565, -3.72181789580636),
#  ('New Forest, United Kingdom', 50.8556349, -1.595562812670837),
#  ('Newark and Sherwood, United Kingdom', 53.10895395, -0.9443017980263069),
#  ('Newcastle upon Tyne, United Kingdom', 54.9738474, -1.6131572),
#  ('Newcastle-under-Lyme, United Kingdom', 53.0117627, -2.2273919),
#  ('Newham, United Kingdom', 51.5300157, 0.029309078788513746),
#  ('Newport, United Kingdom', 51.5882332, -2.9974967),
#  ('Newry Mourne and Down, United Kingdom', 54.1775283, -6.337506),
#  ('Norfolk, United Kingdom', 52.666667, 1.0),
#  ('North Ayrshire, United Kingdom', 55.72785075, -4.727176716786229),
#  ('North Devon, United Kingdom', 51.061456, -3.923923297566936),
#  ('North East, United Kingdom', 54.73141115, -1.7919813357694694),
#  ('North East Derbyshire, United Kingdom', 53.2226728, -1.5239285999071135),
#  ('North East Lincolnshire, United Kingdom',
#   53.53680335,
#   -0.09368101348534888),
#  ('North Hertfordshire, United Kingdom',
#   51.956864949999996,
#   -0.22305090784172493),
#  ('North Kesteven, United Kingdom', 53.07252915, -0.44735386588179665),
#  ('North Lanarkshire, United Kingdom', 55.88305065, -3.946155104761104),
#  ('North Lincolnshire, United Kingdom',
#   53.589744100000004,
#   -0.6023230295256561),
#  ('North Norfolk, United Kingdom', 52.835651999999996, 1.12765976862862),
#  ('North Northamptonshire, United Kingdom',
#   52.417550250000005,
#   -0.6431175410198156),
#  ('North Somerset, United Kingdom', 51.39663045, -2.769128923864108),
#  ('North Tyneside, United Kingdom', 55.02979945, -1.5082559996141889),
#  ('North Warwickshire, United Kingdom', 52.561361, -1.6296344436864212),
#  ('North West, United Kingdom', 52.9559076, -1.1557387),
#  ('North West Leicestershire, United Kingdom',
#   52.770420099999996,
#   -1.3965046691471592),
#  ('North Yorkshire, United Kingdom', 54.13453275, -1.498628491239545),
#  ('Northern Ireland, United Kingdom', 54.5859836, -6.9591554),
#  ('Northumberland, United Kingdom', 55.25, -2.000559),
#  ('Norwich, United Kingdom', 52.6285576, 1.2923954),
#  ('Nottinghamshire, United Kingdom', 53.1459288, -1.0214971168122484),
#  ('Nuneaton and Bedworth, United Kingdom', 52.5010313, -1.4677391944516698),
#  ('Oadby and Wigston, United Kingdom', 52.5870666, -1.0997802143476827),
#  ('Oldham, United Kingdom', 53.5415797, -2.1147831),
#  ('Orkney Islands, United Kingdom', 58.8520573, -3.2869398422535223),
#  ('Outer London, United Kingdom', 51.49455235, -0.017302537414379142),
#  ('Oxford, United Kingdom', 51.7520131, -1.2578499),
#  ('Oxfordshire, United Kingdom', 51.833333, -1.25),
#  ('Pembrokeshire, United Kingdom', 51.8339209, -4.916667),
#  ('Pendle, United Kingdom', 53.87904015, -2.17177953034584),
#  ('Perth and Kinross, United Kingdom', 56.5, -3.75),
#  ('Portsmouth, United Kingdom', 50.800031, -1.0906023),
#  ('Powys, United Kingdom', 52.32714995, -3.3553352394722493),
#  ('Preston, United Kingdom', 53.7593363, -2.6992717),
#  ('Reading, United Kingdom', 51.456659, -0.9696512),
#  ('Redbridge, United Kingdom', 51.5763203, 0.0454097),
#  ('Redcar and Cleveland, United Kingdom', 54.5679056, -1.0054963165760897),
#  ('Redditch, United Kingdom', 52.3057655, -1.9417444),
#  ('Reigate and Banstead, United Kingdom', 51.25164045, -0.18646821513076053),
#  ('Renfrewshire, United Kingdom', 55.833333, -4.5),
#  ('Rhondda Cynon Taf, United Kingdom', 51.66516365, -3.4577557652644413),
#  ('Ribble Valley, United Kingdom', 53.902644050000006, -2.42285603548628),
#  ('Richmond upon Thames, United Kingdom', 51.4405529, -0.3076394377337949),
#  ('Rochdale, United Kingdom', 53.6153659, -2.1557561),
#  ('Rochford, United Kingdom', 51.584060199999996, 0.6787130935643773),
#  ('Rossendale, United Kingdom', 53.6848806, -2.261439758907419),
#  ('Rother, United Kingdom', 50.9514264, 0.5740489897457741),
#  ('Rotherham, United Kingdom', 53.4310417, -1.355187),
#  ('Rugby, United Kingdom', 52.3726682, -1.2620038),
#  ('Runnymede, United Kingdom', 51.3948374, -0.5519609464752796),
#  ('Rushcliffe, United Kingdom', 52.91250105, -1.0110622291190852),
#  ('Rushmoor, United Kingdom', 51.27523885, -0.7693917288354035),
#  ('Rutland, United Kingdom', 52.6423036, -0.6632643077026672),
#  ('Salford, United Kingdom', 53.4877463, -2.2891921),
#  ('Sandwell, United Kingdom', 52.5151278, -2.013562373718973),
#  ('Scotland, United Kingdom', 56.7861112, -4.1140518),
#  ('Scottish Borders, United Kingdom', 55.583333, -2.833333),
#  ('Sefton, United Kingdom', 53.5034122, -2.9714708),
#  ('Sevenoaks, United Kingdom', 51.27452185, 0.1961165562194977),
#  ('Sheffield, United Kingdom', 53.3806626, -1.4702278),
#  ('Shetland Islands, United Kingdom', 60.333333, -1.333333),
#  ('Shropshire, United Kingdom', 52.65233935, -2.64356407027027),
#  ('Slough, United Kingdom', 51.5111014, -0.5940682),
#  ('Solihull, United Kingdom', 52.4130189, -1.7768935),
#  ('Somerset, United Kingdom', 51.161750850000004, -3.0753867062227487),
#  ('South Ayrshire, United Kingdom', 55.299818, -4.645988367016132),
#  ('South Cambridgeshire, United Kingdom',
#   52.179654049999996,
#   -0.0034368130503711347),
#  ('South Derbyshire, United Kingdom', 52.8224616, -1.5026362190000033),
#  ('South East, United Kingdom', 51.4680988, -0.0666715),
#  ('South Gloucestershire, United Kingdom', 51.54919165, -2.4809528173453836),
#  ('South Hams, United Kingdom', 50.3720497, -3.8162519907888086),
#  ('South Holland, United Kingdom', 52.8127195, -0.0012627972576260693),
#  ('South Kesteven, United Kingdom', 52.850266500000004, -0.49519247416097134),
#  ('South Lanarkshire, United Kingdom', 55.5831634, -3.8332212),
#  ('South Norfolk, United Kingdom', 52.5169106, 1.3661677814433835),
#  ('South Oxfordshire, United Kingdom', 51.6366088, -1.0804971850045213),
#  ('South Ribble, United Kingdom', 53.72715265, -2.733006645899704),
#  ('South Staffordshire, United Kingdom', 52.6047717, -2.259164838541728),
#  ('South Tyneside, United Kingdom', 54.969874250000004, -1.4476805465645368),
#  ('South West, United Kingdom', 51.475777699999995, -0.3985761307171166),
#  ('South Yorkshire, United Kingdom', 53.48153335, -1.381042206614959),
#  ('Southampton, United Kingdom', 50.9025349, -1.404189),
#  ('Southend-on-Sea, United Kingdom', 51.5388241, 0.7128137),
#  ('Southwark, United Kingdom', 51.503925, -0.1049663),
#  ('Spelthorne, United Kingdom', 51.4250347, -0.45928607609154937),
#  ('St Albans, United Kingdom', 51.753051, -0.3379675),
#  ('St Helens, United Kingdom', 53.4486075, -2.7359820790816323),
#  ('Stafford, United Kingdom', 52.8063157, -2.1163818),
#  ('Staffordshire, United Kingdom', 52.824694199999996, -2.0074546723348115),
#  ('Staffordshire Moorlands, United Kingdom', 53.07155675, -1.9742007118455929),
#  ('Stevenage, United Kingdom', 51.9016663, -0.2027155),
#  ('Stirling, United Kingdom', 56.1181242, -3.9360012),
#  ('Stockport, United Kingdom', 53.407901, -2.160243),
#  ('Stockton-on-Tees, United Kingdom', 54.564094, -1.3129164),
#  ('Stoke-on-Trent, United Kingdom', 53.0162014, -2.1812607),
#  ('Stratford-on-Avon, United Kingdom', 52.1927803, -1.70634),
#  ('Stroud, United Kingdom', 51.745424, -2.2198605),
#  ('Suffolk, United Kingdom', 52.241001350000005, 1.0466830312565236),
#  ('Sunderland, United Kingdom', 54.9058512, -1.3828727),
#  ('Surrey, United Kingdom', 51.2715316, -0.3414523511290909),
#  ('Surrey Heath, United Kingdom', 51.33588905, -0.6916534194642882),
#  ('Sutton, United Kingdom', 51.357464449999995, -0.17362689496950337),
#  ('Swale, United Kingdom', 51.3367451, 0.801369798606056),
#  ('Swansea, United Kingdom', 51.6195955, -3.9459248),
#  ('Swindon, United Kingdom', 51.5613683, -1.7856853),
#  ('Tameside, United Kingdom', 53.4786454, -2.0770211633705165),
#  ('Tamworth, United Kingdom', 52.6345819, -1.6948438),
#  ('Tandridge, United Kingdom', 51.2393372, -0.0344318),
#  ('Teignbridge, United Kingdom', 50.6125552, -3.6559105980908284),
#  ('Telford and Wrekin, United Kingdom', 52.72144515, -2.500862391509079),
#  ('Tendring, United Kingdom', 51.8753236, 1.1128842),
#  ('Test Valley, United Kingdom', 51.13379045, -1.5182864265840892),
#  ('Tewkesbury, United Kingdom', 51.9925394, -2.1560169592908442),
#  ('Thanet, United Kingdom', 51.353304550000004, 1.3319865973513279),
#  ('Three Rivers, United Kingdom', 51.670137600000004, -0.47380132279242626),
#  ('Thurrock, United Kingdom', 51.5080169, 0.3962817395437666),
#  ('Tonbridge and Malling, United Kingdom', 51.2717306, 0.3566598007492124),
#  ('Torbay, United Kingdom', 50.446247, -3.539499814193785),
#  ('Torfaen, United Kingdom', 51.701480000000004, -3.052050335411309),
#  ('Torridge, United Kingdom', 50.86260145, -4.261205563247918),
#  ('Tower Hamlets, United Kingdom', 51.1288633, 1.2986686),
#  ('Trafford, United Kingdom', 53.41893605, -2.359297161165271),
#  ('Tunbridge Wells, United Kingdom', 51.1371483, 0.2673446),
#  ('Tyne and Wear, United Kingdom', 54.9391774, -1.5948711848097146),
#  ('United Kingdom, United Kingdom', 54.7023545, -3.2765753),
#  ('Uttlesford, United Kingdom', 51.929989500000005, 0.2708364751351891),
#  ('Vale of Glamorgan, United Kingdom', 51.4470646, -3.3988831474846632),
#  ('Vale of White Horse, United Kingdom', 51.654201, -1.4857034705882355),
#  ('Wakefield, United Kingdom', 53.6829541, -1.4967286),
#  ('Wales, United Kingdom', 52.2928116, -3.73893),
#  ('Walsall, United Kingdom', 52.5847949, -1.9822687),
#  ('Waltham Forest, United Kingdom', 51.6892068, -0.0009449),
#  ('Wandsworth, United Kingdom', 51.4570271, -0.1932607),
#  ('Warrington, United Kingdom', 53.3899497, -2.5943178),
#  ('Warwick, United Kingdom', 52.2814519, -1.5815742),
#  ('Warwickshire, United Kingdom', 52.32130635, -1.5536905536661392),
#  ('Watford, United Kingdom', 51.6553875, -0.3957425),
#  ('Waverley, United Kingdom', 55.9519018, -3.1904199),
#  ('Wealden, United Kingdom', 50.94216925, 0.19728012945979825),
#  ('Welwyn Hatfield, United Kingdom', 51.77310555, -0.20951705297322926),
#  ('West Berkshire, United Kingdom', 51.44631345, -1.2758819554702914),
#  ('West Devon, United Kingdom', 50.651997449999996, -4.0743108539440955),
#  ('West Dunbartonshire, United Kingdom', 55.966667, -4.533333),
#  ('West Lancashire, United Kingdom', 53.6109397, -2.856571332507083),
#  ('West Lindsey, United Kingdom', 53.39772845, -0.5035287500531207),
#  ('West Lothian, United Kingdom', 55.916667, -3.5),
#  ('West Midlands, United Kingdom', 52.5050033, -1.964396123331272),
#  ('West Midlands Region, United Kingdom', 53.5657918, -1.3007192),
#  ('West Northamptonshire, United Kingdom', 52.2273432, -0.9967464731954472),
#  ('West Oxfordshire, United Kingdom', 51.84036295, -1.512127443949482),
#  ('West Suffolk, United Kingdom', 52.25813755, 0.617482577783891),
#  ('West Sussex, United Kingdom', 50.94458445, -0.5278477012862655),
#  ('West Yorkshire, United Kingdom', 53.741427099999996, -1.7202003766777243),
#  ('Westmorland and Furness, United Kingdom', 54.4479795, -2.715489112495723),
#  ('Wigan, United Kingdom', 53.5457188, -2.6264624),
#  ('Wiltshire, United Kingdom', 51.25, -1.916667),
#  ('Winchester, United Kingdom', 51.0612766, -1.3131692),
#  ('Windsor and Maidenhead, United Kingdom', 51.4803412, -0.6769505204283354),
#  ('Wirral, United Kingdom', 53.3409714, -3.0500916),
#  ('Woking, United Kingdom', 51.3201891, -0.5564726),
#  ('Wokingham, United Kingdom', 51.4570846, -0.8865370303212372),
#  ('Wolverhampton, United Kingdom', 52.5847651, -2.127567),
#  ('Worcester, United Kingdom', 52.1911849, -2.2206585),
#  ('Worcestershire, United Kingdom', 52.2109495, -2.156955513242221),
#  ('Worthing, United Kingdom', 50.8115402, -0.3699697),
#  ('Wrexham, United Kingdom', 53.0465084, -2.9937869),
#  ('Wychavon, United Kingdom', 52.1803417, -2.0623136726812445),
#  ('Wyre, United Kingdom', 59.1193222, -2.970156643353808),
#  ('Wyre Forest, United Kingdom', 52.385059150000004, -2.2347966141505187),
#  ('York, United Kingdom', 53.9590555, -1.0815361),
#  ('Yorkshire and The Humber, United Kingdom', 53.9318994, -1.1664716608886017)]

# %%
len(coordinates) #checking number of successfully geocoded regions. 402/405 were successful.
# Out:
# 402

# %%
# lsti = []
# lsti.append((geolocator.reverse(f"{coordinates[20][1]},{coordinates[20][2]}").raw["address"], coordinates[20][0]))
# lsti

# %%
coord_list = [] #creating empty list to store results of reverse geocoding.

for i in coordinates:
    coords = f"{i[1]}, {i[2]}"
    address = geolocator.reverse(coords).raw["address"]
    if address is not None:
            coord_list.append(address)
#reverse geocoding the coordinates to find the full address, including state. storing addresses in empty list.

# %%
coord_list
# Out:
# [{'town': 'Alford',
#   'county': 'Aberdeenshire',
#   'ISO3166-2-lvl6': 'GB-ABD',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'AB33 8PX',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Ricardo Noise Test Track',
#   'village': 'Lancing',
#   'city': 'Adur',
#   'county': 'West Sussex',
#   'ISO3166-2-lvl6': 'GB-WSX',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BN15 0RJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Marlborough Drive',
#   'town': 'Belper CP',
#   'village': 'Openwoodgate',
#   'city': 'Amber Valley',
#   'county': 'Derbyshire',
#   'ISO3166-2-lvl6': 'GB-DBY',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DE56 1LB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'isolated_dwelling': 'Cranshade',
#   'town': 'Royal Burgh of Forfar',
#   'county': 'Angus',
#   'ISO3166-2-lvl6': 'GB-ANS',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'DD8 5QL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'office': 'Antrim and Newtownabbey Borough Council',
#   'road': 'Carnmoney Road North',
#   'suburb': 'Mossley',
#   'town': 'Newtownabbey',
#   'county': 'County Antrim',
#   'region': 'Ulster',
#   'ISO3166-2-lvl5': 'IE-U',
#   'state': 'Northern Ireland / Tuaisceart Éireann',
#   'ISO3166-2-lvl4': 'GB-NIR',
#   'postcode': 'BT36 5QA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'man_made': 'North Down and Ards Wastewater Treatment Works',
#   'house_number': '43',
#   'road': 'High Bangor Road',
#   'town': 'Donaghadee',
#   'county': 'County Down',
#   'region': 'Ulster',
#   'ISO3166-2-lvl5': 'IE-U',
#   'state': 'Northern Ireland / Tuaisceart Éireann',
#   'ISO3166-2-lvl4': 'GB-NIR',
#   'postcode': 'BT21 0PB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'hamlet': 'Rhoail',
#   'county': 'Argyll and Bute',
#   'ISO3166-2-lvl6': 'GB-AGB',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'railway': 'Arundel Junction South',
#   'road': 'Murray Rise',
#   'residential': 'Kingley Gate',
#   'town': 'Littlehampton',
#   'village': 'Lyminster',
#   'city': 'Arun',
#   'county': 'West Sussex',
#   'ISO3166-2-lvl6': 'GB-WSX',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BN17 7AY',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': "Lindley's Lane",
#   'town': 'Kirkby-in-Ashfield',
#   'village': 'Annesley',
#   'city': 'Ashfield',
#   'county': 'Nottinghamshire',
#   'ISO3166-2-lvl6': 'GB-NTT',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'NG17 8RR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'tourism': 'Ashford Borough Museum',
#   'road': 'The Churchyard',
#   'suburb': 'South Ashford',
#   'town': 'Ashford',
#   'county': 'Kent',
#   'ISO3166-2-lvl6': 'GB-KEN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'TN23 1QG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'hamlet': 'Rose Green',
#   'village': 'Lindsey',
#   'city': 'Babergh',
#   'county': 'Suffolk',
#   'ISO3166-2-lvl6': 'GB-SFK',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'IP7 6DU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Boyne Road',
#   'suburb': 'Becontree Heath',
#   'city_district': 'London Borough of Barking and Dagenham',
#   'ISO3166-2-lvl8': 'GB-BDG',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'RM10 7JU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'High Street',
#   'suburb': 'High Barnet',
#   'city_district': 'London Borough of Barnet',
#   'ISO3166-2-lvl8': 'GB-BNE',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'EN5 5SB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': 'Fresh Deli Food Plus',
#   'road': 'Peel Parade',
#   'neighbourhood': 'Oakwell',
#   'suburb': 'Keresforth Hill',
#   'town': 'Barnsley',
#   'ISO3166-2-lvl8': 'GB-BNS',
#   'state_district': 'South Yorkshire',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'S70 2RN',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Bonnygate',
#   'town': 'Basildon',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'SS14 2QN',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Harrow Way',
#   'suburb': 'Deane',
#   'village': 'Deane',
#   'city': 'Basingstoke and Deane',
#   'county': 'Hampshire',
#   'ISO3166-2-lvl6': 'GB-HAM',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'RG25 3AN',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Sutton',
#   'village': 'Sutton',
#   'city': 'Bassetlaw',
#   'county': 'Nottinghamshire',
#   'ISO3166-2-lvl6': 'GB-NTT',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'A368',
#   'village': 'Marksbury',
#   'county': 'Bath and North East Somerset',
#   'ISO3166-2-lvl6': 'GB-BAS',
#   'state_district': 'West of England',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BA2 9HN',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Mayes Yard',
#   'suburb': 'Cauldwell',
#   'town': 'Bedford',
#   'county': 'Bedford',
#   'ISO3166-2-lvl6': 'GB-BDF',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'MK40 1SU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'tourism': 'Belfast City Hall',
#   'road': 'Donegall Square South',
#   'quarter': 'Linen Quarter',
#   'city': 'Belfast',
#   'county': 'County Antrim',
#   'region': 'Ulster',
#   'ISO3166-2-lvl5': 'IE-U',
#   'state': 'Northern Ireland / Tuaisceart Éireann',
#   'ISO3166-2-lvl4': 'GB-NIR',
#   'postcode': 'BT1 5GS',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'The George',
#   'road': 'Bexley High Street',
#   'suburb': 'Bexley',
#   'city_district': 'London Borough of Bexley',
#   'ISO3166-2-lvl8': 'GB-BEX',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DA5 1AJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'The River',
#   'road': 'Waterloo Street',
#   'neighbourhood': 'Chinese Quarter',
#   'suburb': 'Digbeth',
#   'village': 'Attwood Green',
#   'city': 'Birmingham',
#   'ISO3166-2-lvl8': 'GB-BIR',
#   'state_district': 'West Midlands Combined Authority',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'B2 5TB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Blaby Dental',
#   'road': 'Lutterworth Road',
#   'suburb': 'Blaby',
#   'village': 'Whetstone',
#   'county': 'Leicestershire',
#   'ISO3166-2-lvl6': 'GB-LEC',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'LE8 4DN',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Edward Street Car Park',
#   'road': 'Edward Street',
#   'suburb': 'Knowle Fold',
#   'town': 'Darwen',
#   'county': 'Blackburn with Darwen',
#   'ISO3166-2-lvl6': 'GB-BBD',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BB3 1AT',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': "St John's",
#   'road': 'Church Street',
#   'suburb': 'Foxhall',
#   'town': 'Blackpool',
#   'county': 'Blackpool',
#   'ISO3166-2-lvl6': 'GB-BPL',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'FY1 1BP',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Victoria',
#   'village': 'Cwm',
#   'county': 'Blaenau Gwent',
#   'ISO3166-2-lvl6': 'GB-BGW',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'NP23 6PZ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Church Street',
#   'suburb': 'Carr Vale',
#   'town': 'Bolsover',
#   'county': 'Derbyshire',
#   'ISO3166-2-lvl6': 'GB-DBY',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'S44 6HA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'historic': 'Cenotaph',
#   'road': 'Victoria Square',
#   'neighbourhood': 'Springfield',
#   'suburb': 'The Haulgh',
#   'town': 'Bolton',
#   'ISO3166-2-lvl8': 'GB-BOL',
#   'state_district': 'Greater Manchester',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BL1 1RJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': "Daisy's Nails",
#   'road': 'Market Place',
#   'quarter': 'Bargate',
#   'suburb': 'Trinity',
#   'town': 'Boston',
#   'county': 'Lincolnshire',
#   'ISO3166-2-lvl6': 'GB-LIN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'PE21 6NH',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '37',
#   'road': 'Bower Road',
#   'suburb': 'Queens Park',
#   'town': 'Bournemouth',
#   'county': 'Bournemouth, Christchurch and Poole',
#   'ISO3166-2-lvl6': 'GB-BCP',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BH8 9HF',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Garswood',
#   'neighbourhood': 'Crown Wood',
#   'town': 'Bracknell',
#   'county': 'Bracknell Forest',
#   'ISO3166-2-lvl6': 'GB-BRC',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'RG12 0TZ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'quarter': 'Little Germany',
#   'suburb': 'Manningham',
#   'city': 'Bradford',
#   'ISO3166-2-lvl8': 'GB-BRD',
#   'state_district': 'West Yorkshire',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'highway': 'Manor Street',
#   'road': 'Manor Street',
#   'neighbourhood': 'Bocking',
#   'town': 'Braintree',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CM7 3YG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Caudle Hill',
#   'suburb': 'Great Cressingham',
#   'village': 'South Pickenham',
#   'city': 'Breckland',
#   'county': 'Norfolk',
#   'ISO3166-2-lvl6': 'GB-NFK',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'PE37 8DR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Brent',
#   'suburb': 'Tinkers Bridge',
#   'town': 'Fenny Stratford',
#   'city': 'Milton Keynes',
#   'county': 'City of Milton Keynes',
#   'ISO3166-2-lvl6': 'GB-MIK',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'MK6 3DL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'tourism': 'Pepperell House',
#   'road': 'High Street',
#   'village': 'Warley',
#   'town': 'Brentwood',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CM14 4RH',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Bridgend Police Station',
#   'road': 'Brackla Street',
#   'suburb': 'Bridgend',
#   'town': 'Bridgend',
#   'county': 'Bridgend',
#   'ISO3166-2-lvl6': 'GB-BGE',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'CF31 1BZ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Harrington Road',
#   'residential': 'Hollingbury',
#   'suburb': 'Preston',
#   'town': 'Hove',
#   'county': 'Brighton and Hove',
#   'ISO3166-2-lvl6': 'GB-BNH',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BN1 6RF',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Church Street',
#   'village': 'Horsham St. Faith',
#   'city': 'Broadland',
#   'county': 'Norfolk',
#   'ISO3166-2-lvl6': 'GB-NFK',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'NR10 3DB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'The Churchill',
#   'road': 'Churchill Way',
#   'quarter': 'Bromley Park',
#   'suburb': 'Plaistow',
#   'city_district': 'London Borough of Bromley',
#   'ISO3166-2-lvl8': 'GB-BRY',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BR1 1EW',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Blackmore Lane',
#   'retail': 'Bromsgrove Retail',
#   'town': 'Bromsgrove',
#   'county': 'Worcestershire',
#   'ISO3166-2-lvl6': 'GB-WOR',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'B60 1AB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '3',
#   'road': 'Station Road',
#   'town': 'Hoddesdon',
#   'county': 'Hertfordshire',
#   'ISO3166-2-lvl6': 'GB-HRT',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'EN10 7HZ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Denton Green Training Centre',
#   'road': 'Denton Green',
#   'suburb': 'Broxtowe',
#   'town': 'Bulwell',
#   'city': 'City of Nottingham',
#   'ISO3166-2-lvl6': 'GB-NGM',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'NG8 6GD',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'historic': 'Buckinghamshire',
#   'ISO3166-2-lvl': 'GB-BKM',
#   'village': 'Stoke Mandeville',
#   'county': 'Buckinghamshire',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'HP17 8UR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': 'Charter Walk Shopping Centre',
#   'road': "St James's Row",
#   'suburb': 'Burnley Wood',
#   'town': 'Burnley',
#   'county': 'Lancashire',
#   'ISO3166-2-lvl6': 'GB-LAN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BB11 1TR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Subway',
#   'house_number': '26',
#   'road': 'Market Street',
#   'quarter': 'Woodhill Fold',
#   'suburb': 'Buckley Wells',
#   'town': 'Bury',
#   'ISO3166-2-lvl8': 'GB-BUR',
#   'state_district': 'Greater Manchester',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BL9 0AJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Park Lane',
#   'suburb': 'Woodfieldside',
#   'village': 'Oakdale',
#   'county': 'Caerphilly',
#   'ISO3166-2-lvl6': 'GB-CAY',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'NP12 0NS',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'village': 'Luddendenfoot',
#   'city': 'Calderdale',
#   'ISO3166-2-lvl8': 'GB-CLD',
#   'state_district': 'West Yorkshire',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'HX2 6JJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'highway': 'Market Street',
#   'road': "St Mary's Street",
#   'suburb': 'Newnham',
#   'city': 'Cambridge',
#   'county': 'Cambridgeshire',
#   'ISO3166-2-lvl6': 'GB-CAM',
#   'state_district': 'Cambridgeshire and Peterborough',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CB2 3NR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Flat Road',
#   'suburb': 'Willingham',
#   'village': 'Willingham',
#   'city': 'South Cambridgeshire',
#   'county': 'Cambridgeshire',
#   'ISO3166-2-lvl6': 'GB-CAM',
#   'state_district': 'Cambridgeshire and Peterborough',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CB24 5JW',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'man_made': 'Primrose Hill Slow Tunnel',
#   'road': 'Alexandra Road',
#   'neighbourhood': 'Swiss Cottage',
#   'suburb': 'South Hampstead',
#   'city_district': 'London Borough of Camden',
#   'ISO3166-2-lvl8': 'GB-CMD',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'NW8 0DJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'leisure': 'Hednesford Hills Raceway',
#   'road': 'Reservoir Road',
#   'town': 'Hednesford',
#   'village': 'Wimblebury',
#   'city': 'Cannock Chase',
#   'county': 'Staffordshire',
#   'ISO3166-2-lvl6': 'GB-STS',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'WS12 1BG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Seven Stars',
#   'house_number': '1',
#   'road': 'Orange Street',
#   'suburb': "The King's Mile",
#   'city': 'Canterbury',
#   'county': 'Kent',
#   'ISO3166-2-lvl6': 'GB-KEN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CT1 2JA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'building': 'Northgate House',
#   'road': 'Kingsway',
#   'neighbourhood': 'Castle Quarter',
#   'suburb': 'Castle',
#   'city': 'Cardiff',
#   'county': 'Cardiff',
#   'ISO3166-2-lvl6': 'GB-CRF',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'CF10 3FD',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Abergwili',
#   'county': 'Sir Gaerfyrddin / Carmarthenshire',
#   'ISO3166-2-lvl6': 'GB-CMN',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'SA32 7HB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Footpath 13',
#   'village': 'South Benfleet',
#   'city': 'Castle Point',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'SS7 1FD',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'tourism': 'Causeway Coast and Glens Heritage Trust',
#   'road': 'Main Street',
#   'village': 'Armoy',
#   'county': 'County Antrim',
#   'region': 'Ulster',
#   'ISO3166-2-lvl5': 'IE-U',
#   'state': 'Northern Ireland / Tuaisceart Éireann',
#   'ISO3166-2-lvl4': 'GB-NIR',
#   'postcode': 'BT53 8RH',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Westoning Road',
#   'farm': 'Clayhill Farm',
#   'suburb': 'Flitton and Greenfield',
#   'village': 'Westoning',
#   'county': 'Central Bedfordshire',
#   'ISO3166-2-lvl6': 'GB-CBF',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'MK45 5BH',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Ystrad Meurig',
#   'county': 'Ceredigion',
#   'ISO3166-2-lvl6': 'GB-CGN',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'leisure': 'Meadow Farm Marina',
#   'road': 'Huston Close',
#   'suburb': 'Barrow upon Soar',
#   'village': 'Mountsorrel',
#   'city': 'Charnwood',
#   'county': 'Leicestershire',
#   'ISO3166-2-lvl6': 'GB-LEC',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'LE12 8LL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'tourism': 'Shire Hall',
#   'road': 'Tindal Square',
#   'suburb': 'Moulsham',
#   'city': 'Chelmsford',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CM1 1EH',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '20',
#   'road': 'Grosvenor Place South',
#   'neighbourhood': 'Sandford',
#   'suburb': 'Fairview',
#   'town': 'Cheltenham',
#   'county': 'Gloucestershire',
#   'ISO3166-2-lvl6': 'GB-GLS',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'GL52 2RX',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'farm': 'The Barn at Solden',
#   'village': 'Souldern',
#   'city': 'Cherwell',
#   'county': 'Oxfordshire',
#   'ISO3166-2-lvl6': 'GB-OXF',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'OX27 7HZ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Smethwick Lane',
#   'suburb': 'Brereton',
#   'county': 'Cheshire East',
#   'ISO3166-2-lvl6': 'GB-CHE',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CW11 2ST',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Hoofield Lane',
#   'hamlet': 'Hoofield',
#   'suburb': 'Clotton Hoofield',
#   'village': 'Clotton',
#   'county': 'Cheshire West and Chester',
#   'ISO3166-2-lvl6': 'GB-CHW',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CH3 9BJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': 'Superdrug',
#   'house_number': '2,4',
#   'road': 'Vicar Lane',
#   'retail': 'Vicar Lane Shopping Centre',
#   'suburb': 'Stonegravels',
#   'village': 'Tapton',
#   'town': 'Chesterfield',
#   'county': 'Derbyshire',
#   'ISO3166-2-lvl6': 'GB-DBY',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'S40 1PY',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Jessie Younghusband Primary School',
#   'road': 'Woodlands Lane',
#   'neighbourhood': 'East Broyle',
#   'suburb': 'Chichester',
#   'city': 'Chichester',
#   'county': 'West Sussex',
#   'ISO3166-2-lvl6': 'GB-WSX',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'PO19 5PA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Boots',
#   'road': 'Market Walk',
#   'suburb': 'Chorley Moor',
#   'town': 'Chorley',
#   'county': 'Lancashire',
#   'ISO3166-2-lvl6': 'GB-LAN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'PR7 1DE',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'City of Aberdeen Central Library',
#   'road': 'Rosemount Viaduct',
#   'suburb': 'City Centre',
#   'city': 'Aberdeen City',
#   'ISO3166-2-lvl6': 'GB-ABE',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'AB25 1GW',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '26',
#   'road': 'William Street',
#   'neighbourhood': 'Windmill Hill',
#   'suburb': 'Totterdown',
#   'city': 'Bristol',
#   'county': 'City of Bristol',
#   'ISO3166-2-lvl6': 'GB-BST',
#   'state_district': 'West of England',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BS3 4TT',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'City of Derby Academy',
#   'road': 'Farmhouse Road',
#   'suburb': 'Sinfin',
#   'city': 'Derby',
#   'county': 'Derby',
#   'ISO3166-2-lvl6': 'GB-DER',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DE24 3AR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'highway': 'Strathmore Street',
#   'road': 'Arklay Street',
#   'suburb': 'Woodside',
#   'city': 'Dundee',
#   'county': 'Dundee City',
#   'ISO3166-2-lvl6': 'GB-DND',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'DD3 7NJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'tourism': 'East End, Waterloo Place',
#   'road': 'Waterloo Place',
#   'neighbourhood': 'Greenside',
#   'suburb': 'New Town/Broughton',
#   'city': 'City of Edinburgh',
#   'ISO3166-2-lvl6': 'GB-EDH',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'EH1 3BG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '9',
#   'road': 'Bellgrove Street',
#   'neighbourhood': 'Bellgrove',
#   'suburb': 'Gallowgate',
#   'city': 'Glasgow',
#   'county': 'Glasgow City',
#   'ISO3166-2-lvl6': 'GB-GLG',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'G31 1AL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Maxwell Street',
#   'suburb': 'Garden Village',
#   'city': 'Hull',
#   'county': 'Kingston upon Hull',
#   'ISO3166-2-lvl6': 'GB-KHL',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'HU8 8DG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'tourism': 'Guildhall',
#   'road': 'Guildhall Yard',
#   'quarter': 'Cheap',
#   'city_district': 'Cheap',
#   'city': 'City of London',
#   'ISO3166-2-lvl6': 'GB-LND',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'EC2P 2SA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'tourism': 'Menelaus (aka "Ronnie" or "Oscar")',
#   'road': 'Old Market Square',
#   'neighbourhood': 'Lace Market',
#   'suburb': 'The Meadows',
#   'city': 'City of Nottingham',
#   'ISO3166-2-lvl6': 'GB-NGM',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'NG1 2JX',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'building': 'Clipper Logistics Group',
#   'road': 'Ivatt Way',
#   'suburb': 'Westwood',
#   'city': 'Peterborough',
#   'county': 'City of Peterborough',
#   'ISO3166-2-lvl6': 'GB-PTE',
#   'state_district': 'Cambridgeshire and Peterborough',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'PE3 7EZ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Swansea City Bus Station',
#   'road': 'Plymouth Street',
#   'suburb': 'Mount Pleasant',
#   'city': 'Swansea',
#   'county': 'Swansea',
#   'ISO3166-2-lvl6': 'GB-SWA',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'SA1 3QX',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Westminster City Hall',
#   'house_number': '62-64',
#   'road': 'Victoria Street',
#   'quarter': 'Westminster',
#   'suburb': 'Victoria',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'SW1E 6QP',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'village': 'Devonside',
#   'county': 'Clackmannanshire',
#   'ISO3166-2-lvl6': 'GB-CLK',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'FK13 6HU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': 'Tesco Express',
#   'house_number': '33-34',
#   'road': 'High Street',
#   'city': 'Colchester',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CO1 1DH',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Bro Garmon',
#   'town': 'Llanrwst',
#   'county': 'Conwy',
#   'ISO3166-2-lvl6': 'GB-CWY',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'LL26 0NS',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'hamlet': 'Lowertown',
#   'suburb': 'Luxulyan',
#   'county': 'Cornwall',
#   'ISO3166-2-lvl6': 'GB-CON',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'PL30 5DU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Compton Abdale',
#   'village': 'Compton Abdale',
#   'city': 'Cotswold',
#   'county': 'Gloucestershire',
#   'ISO3166-2-lvl6': 'GB-GLS',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'GL54 4DL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'isolated_dwelling': 'Witton Park Farm',
#   'suburb': 'Evenwood and Barony',
#   'village': 'Low Etherley',
#   'county': 'County Durham',
#   'ISO3166-2-lvl6': 'GB-DUR',
#   'state_district': 'North East',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DL14 0DQ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'historic': 'Statue of Lady Godiva',
#   'road': 'Broadgate',
#   'suburb': 'Hillfields',
#   'city': 'Coventry',
#   'ISO3166-2-lvl8': 'GB-COV',
#   'state_district': 'West Midlands Combined Authority',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CV1 1LL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Ringwood Close',
#   'village': 'Tilgate',
#   'town': 'Crawley',
#   'county': 'West Sussex',
#   'ISO3166-2-lvl6': 'GB-WSX',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'RH10 6HJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '23',
#   'road': 'Scarbrook Road',
#   'suburb': 'Broad Green',
#   'city_district': 'London Borough of Croydon',
#   'ISO3166-2-lvl8': 'GB-CRY',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CR0 1SQ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Isel Road',
#   'suburb': 'Slatefell',
#   'town': 'Cockermouth',
#   'county': 'Cumberland',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CA13 9SA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'New Road',
#   'hamlet': 'Castle Village',
#   'suburb': 'Berkhamsted',
#   'town': 'Berkhamsted',
#   'city': 'Dacorum',
#   'county': 'Hertfordshire',
#   'ISO3166-2-lvl6': 'GB-HRT',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'HP4 2QB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'historic': 'Market Cross',
#   'road': 'West Row',
#   'suburb': 'Bank Top',
#   'town': 'Darlington',
#   'county': 'Darlington',
#   'ISO3166-2-lvl6': 'GB-DAL',
#   'state_district': 'Tees Valley',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DL1 5PW',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Greggs',
#   'house_number': '28',
#   'road': 'High Street',
#   'suburb': 'Temple Hill',
#   'town': 'Dartford',
#   'county': 'Kent',
#   'ISO3166-2-lvl6': 'GB-KEN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DA1 1BZ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Cyffylliog',
#   'village': 'Y Bontuchel',
#   'county': 'Denbighshire',
#   'ISO3166-2-lvl6': 'GB-DEN',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'LL15 2DD',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': "Lovers' Walk",
#   'village': 'Matlock Bath CP',
#   'town': 'Matlock',
#   'city': 'Derbyshire Dales',
#   'county': 'Derbyshire',
#   'ISO3166-2-lvl6': 'GB-DBY',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DE4 3NS',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Stunstead Lane',
#   'village': 'Brassington CP',
#   'city': 'Derbyshire Dales',
#   'county': 'Derbyshire',
#   'ISO3166-2-lvl6': 'GB-DBY',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DE4 2PF',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'building': 'Derry City and Strabane District Council',
#   'road': 'Derry Road',
#   'town': 'Strabane',
#   'county': 'County Tyrone',
#   'region': 'Ulster',
#   'ISO3166-2-lvl5': 'IE-U',
#   'state': 'Northern Ireland / Tuaisceart Éireann',
#   'ISO3166-2-lvl4': 'GB-NIR',
#   'postcode': 'BT82 8AQ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'A30',
#   'suburb': 'Tedburn St. Mary',
#   'village': 'Tedburn St Mary',
#   'city': 'Teignbridge',
#   'county': 'Devon',
#   'ISO3166-2-lvl6': 'GB-DEV',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'EX6 6RP',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': 'Walkabout',
#   'road': 'Priory Walk',
#   'quarter': 'City Centre',
#   'suburb': 'Hyde Park',
#   'city': 'Doncaster',
#   'ISO3166-2-lvl8': 'GB-DNC',
#   'state_district': 'South Yorkshire',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DN1 1TS',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': "Drake's Lane",
#   'suburb': 'Cheselbourne',
#   'village': 'Cheselbourne',
#   'county': 'Dorset',
#   'ISO3166-2-lvl6': 'GB-DOR',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DT2 7NT',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Lloyds Bank',
#   'road': 'Market Square',
#   'suburb': 'Clarendon',
#   'town': 'Dover',
#   'county': 'Kent',
#   'ISO3166-2-lvl6': 'GB-KEN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CT16 1NB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': 'Ladbrokes',
#   'road': 'New Street',
#   'suburb': 'Eve Hill',
#   'village': 'Dixons Green',
#   'town': 'Dudley',
#   'ISO3166-2-lvl8': 'GB-DUD',
#   'state_district': 'West Midlands Combined Authority',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DY1 1PQ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'county': 'Dumfries and Galloway',
#   'ISO3166-2-lvl6': 'GB-DGY',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '38',
#   'road': 'High Street',
#   'city_district': 'London Borough of Ealing',
#   'ISO3166-2-lvl8': 'GB-EAL',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'W5 5DB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'village': 'Sorn',
#   'county': 'East Ayrshire',
#   'ISO3166-2-lvl6': 'GB-EAY',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'KA5 6NE',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'leisure': 'Kingfishers Bridge NR',
#   'road': 'High Fen Road',
#   'village': 'Wicken',
#   'city': 'East Cambridgeshire',
#   'county': 'Cambridgeshire',
#   'ISO3166-2-lvl6': 'GB-CAM',
#   'state_district': 'Cambridgeshire and Peterborough',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CB7 5XL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'town': 'Sidmouth',
#   'city': 'East Devon',
#   'county': 'Devon',
#   'ISO3166-2-lvl6': 'GB-DEV',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'EX10 0QQ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Forth and Clyde Canal Towpath',
#   'suburb': 'Westermains',
#   'town': 'Kirkintilloch',
#   'county': 'East Dunbartonshire',
#   'ISO3166-2-lvl6': 'GB-EDU',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'G66 1RH',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Newton Valence',
#   'city': 'East Hampshire',
#   'county': 'Hampshire',
#   'ISO3166-2-lvl6': 'GB-HAM',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'GU34 3SF',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'hamlet': 'Latchford',
#   'suburb': 'Standon',
#   'village': 'Barwick',
#   'city': 'East Hertfordshire',
#   'county': 'Hertfordshire',
#   'ISO3166-2-lvl6': 'GB-HRT',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'SG11 1RB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Bluestone Heath Road',
#   'isolated_dwelling': 'Windy Nook',
#   'suburb': 'South Ormsby cum Ketsby',
#   'city': 'East Lindsey',
#   'county': 'Lincolnshire',
#   'ISO3166-2-lvl6': 'GB-LIN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'LN11 8RF',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'B6369',
#   'village': 'Gifford',
#   'county': 'East Lothian',
#   'ISO3166-2-lvl6': 'GB-ELN',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'EH41 4JD',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Colsterworth Road',
#   'isolated_dwelling': 'Stainby Lodge',
#   'suburb': 'Gunby and Stainby',
#   'village': 'Stainby',
#   'city': 'South Kesteven',
#   'county': 'Lincolnshire',
#   'ISO3166-2-lvl6': 'GB-LIN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'NG33 5RH',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'M77',
#   'suburb': 'Maidenhill',
#   'town': 'Newton Mearns',
#   'county': 'East Renfrewshire',
#   'ISO3166-2-lvl6': 'GB-ERW',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'G77 6RX',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Dalton Holme',
#   'village': 'Lund',
#   'county': 'East Riding of Yorkshire',
#   'ISO3166-2-lvl6': 'GB-ERY',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'YO25 9DF',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Stafford Road',
#   'hamlet': "Blount's Green",
#   'town': 'Uttoxeter',
#   'village': 'Bramshall',
#   'city': 'East Staffordshire',
#   'county': 'Staffordshire',
#   'ISO3166-2-lvl6': 'GB-STS',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'ST14 8QA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'hamlet': 'Rendham',
#   'city': 'East Suffolk',
#   'county': 'Suffolk',
#   'ISO3166-2-lvl6': 'GB-SFK',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'IP17 2AR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': "Herring's Road",
#   'residential': "Herring's Farm",
#   'suburb': 'Dallington',
#   'village': 'Dallington',
#   'city': 'Rother',
#   'county': 'East Sussex',
#   'ISO3166-2-lvl6': 'GB-ESX',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'TN21 9NL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'B1063',
#   'hamlet': 'Silverley',
#   'village': 'Ashley',
#   'city': 'East Cambridgeshire',
#   'county': 'Cambridgeshire',
#   'ISO3166-2-lvl6': 'GB-CAM',
#   'state_district': 'Cambridgeshire and Peterborough',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CB8 8PA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Meads Road',
#   'suburb': 'Meads',
#   'town': 'Eastbourne',
#   'county': 'East Sussex',
#   'ISO3166-2-lvl6': 'GB-ESX',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BN21 4EU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '7;7A',
#   'road': 'Westward Road',
#   'suburb': 'Wildern',
#   'town': 'Hedge End',
#   'county': 'Hampshire',
#   'ISO3166-2-lvl6': 'GB-HAM',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'SO30 4NP',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'village': 'Elmbridge',
#   'city': 'Wychavon',
#   'county': 'Worcestershire',
#   'ISO3166-2-lvl6': 'GB-WOR',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'WR9 0DA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': "Nando's",
#   'house_number': '2',
#   'road': 'The Town',
#   'suburb': 'Southbury',
#   'town': 'Enfield',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'EN2 6LE',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Coventry Road',
#   'suburb': 'Sapcote',
#   'village': 'Sapcote',
#   'county': 'Leicestershire',
#   'ISO3166-2-lvl6': 'GB-LEC',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'LE9 4JU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'building': 'Institute of Chartered Accountants in England and Wales',
#   'house_number': '1',
#   'road': 'Moorgate Place',
#   'city_district': 'Coleman Street',
#   'city': 'City of London',
#   'ISO3166-2-lvl6': 'GB-LND',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'EC2R 6EA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Epping New Road',
#   'town': 'Loughton',
#   'city': 'Epping Forest',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CM16 5HP',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Royal Mail',
#   'road': 'Chase Road',
#   'town': 'Epsom',
#   'city': 'Epsom and Ewell',
#   'county': 'Surrey',
#   'ISO3166-2-lvl6': 'GB-SRY',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'KT19 8TL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'tourism': "Hermit's Wood & All Saints Church",
#   'road': 'The Village',
#   'village': 'Dale Abbey',
#   'city': 'Erewash',
#   'county': 'Derbyshire',
#   'ISO3166-2-lvl6': 'GB-DBY',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DE7 4PN',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Chelmer Valley High School',
#   'road': 'Broomfield Cycleway',
#   'hamlet': 'Parsonage Green',
#   'suburb': 'Broomfield',
#   'city': 'Chelmsford',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CM1 7ER',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'New North Road',
#   'suburb': 'Newtown',
#   'city': 'Exeter',
#   'county': 'Devon',
#   'ISO3166-2-lvl6': 'GB-DEV',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'EX1 1GA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'historic': 'Falkirk Steeple and Visitor Information Point',
#   'road': 'High Street',
#   'suburb': 'Callendar Park',
#   'town': 'Falkirk',
#   'county': 'Falkirk',
#   'ISO3166-2-lvl6': 'GB-FAL',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'FK1 1DZ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': 'Fareham Shopping Centre',
#   'road': 'West Street',
#   'neighbourhood': 'Wallington',
#   'town': 'Fareham',
#   'county': 'Hampshire',
#   'ISO3166-2-lvl6': 'GB-HAM',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'PO16 0PQ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'locality': 'West Fen',
#   'town': 'March',
#   'city': 'Fenland',
#   'county': 'Cambridgeshire',
#   'ISO3166-2-lvl6': 'GB-CAM',
#   'state_district': 'Cambridgeshire and Peterborough',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'PE15 0AP',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'locality': 'Camagh',
#   'county': 'County Fermanagh',
#   'region': 'Ulster',
#   'ISO3166-2-lvl5': 'IE-U',
#   'state': 'Northern Ireland / Tuaisceart Éireann',
#   'ISO3166-2-lvl4': 'GB-NIR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'town': 'Cupar',
#   'county': 'Fife',
#   'ISO3166-2-lvl6': 'GB-FIF',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'KY15 4PL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Northop College',
#   'road': 'Gwibffordd Gogledd Cymru / North Wales Expressway',
#   'suburb': 'Northop',
#   'village': 'Flint Mountain',
#   'county': 'Flintshire',
#   'ISO3166-2-lvl6': 'GB-FLN',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'CH6 5QU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Lower Wall Road',
#   'village': 'Burmarsh',
#   'city': 'Folkestone and Hythe',
#   'county': 'Kent',
#   'ISO3166-2-lvl6': 'GB-KEN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CT21 4NW',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Mineral Loop',
#   'suburb': 'Ruspidge and Soudley',
#   'village': 'Ruspidge',
#   'city': 'Forest of Dean',
#   'county': 'Gloucestershire',
#   'ISO3166-2-lvl6': 'GB-GLS',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'GL14 3HU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Weeton Road',
#   'suburb': 'Medlar-with-Wesham',
#   'village': 'Weeton',
#   'city': 'Fylde',
#   'county': 'Lancashire',
#   'ISO3166-2-lvl6': 'GB-LAN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'PR4 3WA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'tourism': 'Halo',
#   'road': 'Trinity Square',
#   'neighbourhood': 'Ochre Yards',
#   'suburb': 'Bensham',
#   'town': 'Gateshead',
#   'ISO3166-2-lvl8': 'GB-GAT',
#   'county': 'Tyne and Wear',
#   'state_district': 'North East',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'NE8 1AG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': "George's Lane",
#   'village': 'Calverton CP',
#   'town': 'Arnold',
#   'city': 'Gedling',
#   'county': 'Nottinghamshire',
#   'ISO3166-2-lvl6': 'GB-NTT',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'NG5 8PX',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Kokoro',
#   'road': 'Northgate Street',
#   'hamlet': 'Kings Barton',
#   'city': 'Gloucester',
#   'county': 'Gloucestershire',
#   'ISO3166-2-lvl6': 'GB-GLS',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'GL1 2AP',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Painswick Road',
#   'hamlet': 'Pincott',
#   'suburb': 'Upton St. Leonards',
#   'village': 'Cranham',
#   'town': 'Stroud',
#   'county': 'Gloucestershire',
#   'ISO3166-2-lvl6': 'GB-GLS',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'GL4 8ET',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '114',
#   'road': 'High Street',
#   'suburb': "Priddy's Hard",
#   'town': 'Gosport',
#   'county': 'Hampshire',
#   'ISO3166-2-lvl6': 'GB-HAM',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'PO12 1DU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Scotland Lane',
#   'hamlet': 'Battle Street',
#   'suburb': 'Cobham',
#   'village': 'Cobham',
#   'city': 'Gravesham',
#   'county': 'Kent',
#   'ISO3166-2-lvl6': 'GB-KEN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DA12 3DB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Wood End Lane',
#   'farm': 'Wood End',
#   'suburb': 'Redmire',
#   'village': 'Redmire',
#   'county': 'North Yorkshire',
#   'ISO3166-2-lvl6': 'GB-NYK',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DL8 4DY',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': 'Hair 4U',
#   'road': 'Regent Road',
#   'suburb': 'Northgate',
#   'town': 'Great Yarmouth',
#   'county': 'Norfolk',
#   'ISO3166-2-lvl6': 'GB-NFK',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'NR30 2AH',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'highway': 'Eccles Road/Worsley Road',
#   'road': 'Eccles Road',
#   'suburb': 'Newtown',
#   'town': 'Swinton',
#   'city': 'Salford',
#   'ISO3166-2-lvl8': 'GB-SLF',
#   'state_district': 'Greater Manchester',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'M27 5PG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'man_made': 'College Tunnel',
#   'road': 'Romney Road',
#   'suburb': 'East Greenwich',
#   'city_district': 'Royal Borough of Greenwich',
#   'ISO3166-2-lvl8': 'GB-GRE',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'SE10 9LS',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '94',
#   'road': 'High Street',
#   'suburb': 'Charlotteville',
#   'town': 'Guildford',
#   'county': 'Surrey',
#   'ISO3166-2-lvl6': 'GB-SRY',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'GU1 3HE',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'locality': 'Craig Aderyn',
#   'suburb': 'Trawsfynydd',
#   'county': 'Gwynedd',
#   'ISO3166-2-lvl6': 'GB-GWN',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'LL41 4TR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '15',
#   'road': 'Elsdale Street',
#   'neighbourhood': 'Victoria Park Village',
#   'suburb': 'Homerton',
#   'city_district': 'London Borough of Hackney',
#   'ISO3166-2-lvl8': 'GB-HCK',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'E9 6QW',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'building': 'Tesco Warehouse',
#   'road': 'De Soto Road',
#   'industrial': 'West Bank Dock Estate',
#   'suburb': 'Ditton Marsh',
#   'town': 'Runcorn',
#   'county': 'Halton',
#   'ISO3166-2-lvl6': 'GB-HAL',
#   'state_district': 'Liverpool City Region',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'WA8 0PB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '117',
#   'road': 'Hammersmith Grove',
#   'suburb': 'Brook Green',
#   'city_district': 'London Borough of Hammersmith and Fulham',
#   'ISO3166-2-lvl8': 'GB-HMF',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'W6 0NJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Petersfield Road',
#   'suburb': 'Cheriton',
#   'village': 'Cheriton',
#   'city': 'Winchester',
#   'county': 'Hampshire',
#   'ISO3166-2-lvl6': 'GB-HAM',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'SO24 0NU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Cranoe Road',
#   'suburb': 'Tur Langton',
#   'village': 'Tur Langton',
#   'city': 'Harborough',
#   'county': 'Leicestershire',
#   'ISO3166-2-lvl6': 'GB-LEC',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'LE8 0PD',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '77',
#   'road': 'Hampden Road',
#   'neighbourhood': 'Harringay Ladder',
#   'suburb': 'Harringay',
#   'city_district': 'London Borough of Haringey',
#   'ISO3166-2-lvl8': 'GB-HRY',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'N8 0HU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'The High',
#   'town': 'Harlow',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CM20 1HH',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Wolseley Road',
#   'suburb': 'Wealdstone',
#   'city_district': 'London Borough of Harrow',
#   'ISO3166-2-lvl8': 'GB-HRW',
#   'city': 'London',
#   'state_district': 'Greater London',
# ...
#   'postcode': 'RM16 3DD',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Seven Mile Lane',
#   'suburb': 'Mereworth',
#   'village': 'Mereworth',
#   'city': 'Tonbridge and Malling',
#   'county': 'Kent',
#   'ISO3166-2-lvl6': 'GB-KEN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'ME18 5QY',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'locality': 'Corbyn Head',
#   'suburb': 'Livermead',
#   'town': 'Torquay',
#   'county': 'Torbay',
#   'ISO3166-2-lvl6': 'GB-TOB',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'TQ2 6RJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Tranch Road',
#   'suburb': 'Tranch',
#   'town': 'Pontypool',
#   'county': 'Torfaen',
#   'ISO3166-2-lvl6': 'GB-TOF',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'NP4 6AY',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'hamlet': 'Milton Damerel',
#   'village': 'Bradford',
#   'city': 'Torridge',
#   'county': 'Devon',
#   'ISO3166-2-lvl6': 'GB-DEV',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'EX22 7AR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Wyndham Road',
#   'suburb': 'Tower Hamlets',
#   'town': 'Dover',
#   'county': 'Kent',
#   'ISO3166-2-lvl6': 'GB-KEN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CT17 0BH',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Thirsk Avenue',
#   'suburb': 'Ashton upon Mersey',
#   'village': 'West Timperley',
#   'city': 'Trafford',
#   'ISO3166-2-lvl8': 'GB-TRF',
#   'state_district': 'Greater Manchester',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'M33 4GJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Royal Mail',
#   'road': 'Goods Station Road',
#   'neighbourhood': 'Royal Wells Park',
#   'suburb': 'St James',
#   'town': 'Royal Tunbridge Wells',
#   'city': 'Tunbridge Wells',
#   'county': 'Kent',
#   'ISO3166-2-lvl6': 'GB-KEN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'TN1 2DQ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Low Fell',
#   'town': 'Gateshead',
#   'ISO3166-2-lvl8': 'GB-GAT',
#   'county': 'Tyne and Wear',
#   'state_district': 'North East',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'NE9 5YL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Bothel and Threapland',
#   'village': 'Sunderland',
#   'county': 'Cumberland',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CA13 9SS',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Chickney',
#   'village': 'Chickney',
#   'city': 'Uttlesford',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Llantrithyd Road',
#   'suburb': 'Llanfair',
#   'village': 'St Hilary',
#   'county': 'Vale of Glamorgan',
#   'ISO3166-2-lvl6': 'GB-VGL',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'CF71 7DR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Buckland Road',
#   'village': 'Charney Bassett',
#   'city': 'Vale of White Horse',
#   'county': 'Oxfordshire',
#   'ISO3166-2-lvl6': 'GB-OXF',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'OX12 0EL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Wakefield Cathedral',
#   'road': 'Westmorland Street',
#   'suburb': 'Eastmoor',
#   'city': 'Wakefield',
#   'ISO3166-2-lvl8': 'GB-WKF',
#   'state_district': 'West Yorkshire',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'WF1 1HG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': "Monk's Trod",
#   'suburb': 'Ysbyty Ystwyth',
#   'county': 'Ceredigion',
#   'ISO3166-2-lvl6': 'GB-CGN',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'highway': 'A',
#   'road': "Saint Paul's Street",
#   'suburb': 'Caldmore',
#   'town': 'Walsall',
#   'ISO3166-2-lvl8': 'GB-WLL',
#   'state_district': 'West Midlands Combined Authority',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'WS1 1NJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'building': 'Abbey Storehouse Ruins',
#   'road': 'Abbey View',
#   'suburb': 'Waltham Abbey',
#   'city': 'Epping Forest',
#   'municipality': 'Essex',
#   'ISO3166-2-lvl6': 'GB-ESS',
#   'county': 'Essex',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'EN9 1XQ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'building': "Cooper's Lofts",
#   'house_number': '5',
#   'road': 'Bubbling Well Square',
#   'residential': 'The Ram Quarter',
#   'suburb': 'Earlsfield',
#   'city_district': 'London Borough of Wandsworth',
#   'ISO3166-2-lvl8': 'GB-WND',
#   'city': 'London',
#   'state_district': 'Greater London',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'SW18 1UJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': 'Golden Square Shopping Centre',
#   'road': 'Sankey Street',
#   'quarter': 'Bank Quay',
#   'suburb': 'Howley',
#   'town': 'Warrington',
#   'county': 'Warrington',
#   'ISO3166-2-lvl6': 'GB-WRT',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'WA1 1SB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'St Nicholas',
#   'road': 'St Nicholas Church Street',
#   'suburb': 'Cliff Hill',
#   'town': 'Warwick',
#   'county': 'Warwickshire',
#   'ISO3166-2-lvl6': 'GB-WAR',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CV34 4JD',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Kenilworth Road',
#   'suburb': 'Blackdown',
#   'town': 'Warwick',
#   'county': 'Warwickshire',
#   'ISO3166-2-lvl6': 'GB-WAR',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CV32 6QT',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': 'Poundland',
#   'house_number': '77;79',
#   'road': 'High Street',
#   'town': 'Watford',
#   'county': 'Hertfordshire',
#   'ISO3166-2-lvl6': 'GB-HRT',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'WD17 2DQ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'building': 'Edinburgh Waverley',
#   'road': "North Gray's Close",
#   'suburb': 'Canongate',
#   'city': 'City of Edinburgh',
#   'ISO3166-2-lvl6': 'GB-EDH',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'EH1 1SJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Fox Hunt Green',
#   'farm': 'Kirby Farm',
#   'suburb': 'Heathfield and Waldron',
#   'village': 'Waldron',
#   'city': 'Wealden',
#   'county': 'East Sussex',
#   'ISO3166-2-lvl6': 'GB-ESX',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'TN21 0RY',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '19',
#   'road': 'Greenfield',
#   'suburb': 'The Ryde',
#   'town': 'Hatfield',
#   'village': 'Stanborough',
#   'city': 'Welwyn Hatfield',
#   'county': 'Hertfordshire',
#   'ISO3166-2-lvl6': 'GB-HRT',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'AL9 5HW',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Sawmill Road',
#   'industrial': 'Red Shute Hill Industrial Estate',
#   'village': 'Cold Ash',
#   'county': 'West Berkshire',
#   'ISO3166-2-lvl6': 'GB-WBK',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'RG18 9QX',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Lydford',
#   'city': 'West Devon',
#   'county': 'Devon',
#   'ISO3166-2-lvl6': 'GB-DEV',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'isolated_dwelling': 'Garshake',
#   'town': 'Dumbarton',
#   'county': 'West Dunbartonshire',
#   'ISO3166-2-lvl6': 'GB-WDU',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'G82 3PY',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Crabtree Lane',
#   'suburb': 'Burscough Bridge',
#   'village': 'Burscough',
#   'city': 'West Lancashire',
#   'county': 'Lancashire',
#   'ISO3166-2-lvl6': 'GB-LAN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'L40 0RW',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Gainsborough Road',
#   'village': 'Glentham CP',
#   'city': 'West Lindsey',
#   'county': 'Lincolnshire',
#   'ISO3166-2-lvl6': 'GB-LIN',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'LN8 2AN',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '51',
#   'road': 'Longwall Gardens',
#   'village': 'Uphall Station',
#   'county': 'West Lothian',
#   'ISO3166-2-lvl6': 'GB-WLN',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'EH54 5FG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'railway': 'The Hawthorns',
#   'road': 'Moyses Croft',
#   'town': 'Smethwick',
#   'city': 'Sandwell',
#   'ISO3166-2-lvl8': 'GB-SAW',
#   'state_district': 'West Midlands Combined Authority',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'B66 2HT',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Churchfield Road',
#   'hamlet': 'Frickley',
#   'suburb': 'Clayton with Frickley',
#   'village': 'Clayton',
#   'city': 'Doncaster',
#   'ISO3166-2-lvl8': 'GB-DNC',
#   'state_district': 'South Yorkshire',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DN5 7BX',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'M1',
#   'suburb': 'Kislingbury',
#   'village': 'Rothersthorpe',
#   'county': 'West Northamptonshire',
#   'ISO3166-2-lvl6': 'GB-WNH',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'NN7 4BA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'neighbourhood': 'Lower End',
#   'village': 'Leafield',
#   'city': 'West Oxfordshire',
#   'county': 'Oxfordshire',
#   'ISO3166-2-lvl6': 'GB-OXF',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'OX29 9QR',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'industrial': 'Symonds Farm Business Park',
#   'suburb': 'The Saxhams',
#   'village': 'Little Saxham',
#   'city': 'West Suffolk',
#   'county': 'Suffolk',
#   'ISO3166-2-lvl6': 'GB-SFK',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'IP28 6RE',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'London Road',
#   'hamlet': 'Hardham',
#   'village': 'Coldwaltham',
#   'town': 'Horsham',
#   'county': 'West Sussex',
#   'ISO3166-2-lvl6': 'GB-WSX',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'RH20 1LB',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'M62',
#   'village': 'Hunsworth',
#   'city': 'Kirklees',
#   'ISO3166-2-lvl8': 'GB-KIR',
#   'state_district': 'West Yorkshire',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BD19 4TY',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'locality': 'Crookdale',
#   'suburb': 'Shap Rural',
#   'county': 'Cumbria',
#   'ISO3166-2-lvl6': 'GB-CMA',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'LA8 9LG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'building': 'Derby House',
#   'road': 'Scholes',
#   'suburb': 'Longshoot',
#   'town': 'Wigan',
#   'ISO3166-2-lvl8': 'GB-WGN',
#   'state_district': 'Greater Manchester',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'WN1 3QJ',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'suburb': 'Tilshead',
#   'village': 'Tilshead',
#   'county': 'Wiltshire',
#   'ISO3166-2-lvl6': 'GB-WIL',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Winchester Cathedral',
#   'road': 'Cathedral Close',
#   'suburb': 'The Close',
#   'city': 'Winchester',
#   'county': 'Hampshire',
#   'ISO3166-2-lvl6': 'GB-HAM',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'SO23 9LS',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': '52',
#   'farm': 'Meadow Lane Farm',
#   'village': 'Bray',
#   'county': 'Windsor and Maidenhead',
#   'ISO3166-2-lvl6': 'GB-WNM',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'SL6 2NX',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Brimstage Road',
#   'village': 'Brimstage',
#   'municipality': 'Wirral',
#   'ISO3166-2-lvl8': 'GB-WRL',
#   'state_district': 'Liverpool City Region',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'CH63 6JA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'GU21 29',
#   'road': 'Crown Square',
#   'village': 'Horsell',
#   'town': 'Woking',
#   'county': 'Surrey',
#   'ISO3166-2-lvl6': 'GB-SRY',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'GU21 6HX',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'house_number': '54',
#   'road': 'Donaldson Way',
#   'suburb': 'Woodley',
#   'town': 'Reading',
#   'ISO3166-2-lvl6': 'GB-WOK',
#   'county': 'Wokingham',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'RG5 4XL',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': 'Mander Centre',
#   'road': 'Victoria Street',
#   'city': 'Wolverhampton',
#   'ISO3166-2-lvl8': 'GB-WLV',
#   'state_district': 'West Midlands Combined Authority',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'WV1 3NP',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'The Guildhall',
#   'road': 'High Street',
#   'suburb': 'Red Hill',
#   'city': 'Worcester',
#   'county': 'Worcestershire',
#   'ISO3166-2-lvl6': 'GB-WOR',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'WR1 2EY',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Pershore Lane',
#   'village': 'Tibberton',
#   'city': 'Wychavon',
#   'county': 'Worcestershire',
#   'ISO3166-2-lvl6': 'GB-WOR',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'WR4 0AN',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Royal Mail',
#   'road': 'Warwick Street',
#   'town': 'Worthing',
#   'county': 'West Sussex',
#   'ISO3166-2-lvl6': 'GB-WSX',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'BN11 1EY',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'shop': 'Gerrards',
#   'road': 'Queens Square',
#   'suburb': 'City Centre',
#   'city': 'Wrexham',
#   'county': 'Wrexham',
#   'ISO3166-2-lvl6': 'GB-WRX',
#   'state': 'Cymru / Wales',
#   'ISO3166-2-lvl4': 'GB-WLS',
#   'postcode': 'LL11 1AP',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Upton Snodsbury Road',
#   'village': 'Naunton Beauchamp',
#   'city': 'Wychavon',
#   'county': 'Worcestershire',
#   'ISO3166-2-lvl6': 'GB-WOR',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'WR7 4NU',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Hall (old C19 schoolhouse)',
#   'road': 'Russness Road',
#   'village': 'The Brinian',
#   'county': 'Orkney Islands',
#   'ISO3166-2-lvl6': 'GB-ORK',
#   'state': 'Alba / Scotland',
#   'ISO3166-2-lvl4': 'GB-SCT',
#   'postcode': 'KW17 2QA',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'Chester Road North',
#   'suburb': 'Aggborough',
#   'town': 'Kidderminster',
#   'village': 'Comberton',
#   'city': 'Wyre Forest',
#   'county': 'Worcestershire',
#   'ISO3166-2-lvl6': 'GB-WOR',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'DY10 1TP',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'amenity': 'Costa',
#   'house_number': '15',
#   'road': 'Parliament Street',
#   'suburb': 'Bishophill',
#   'city': 'York',
#   'county': 'York',
#   'ISO3166-2-lvl6': 'GB-YOR',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'YO1 8SG',
#   'country': 'United Kingdom',
#   'country_code': 'gb'},
#  {'road': 'North Field Lane',
#   'village': 'Askham Bryan',
#   'county': 'York',
#   'ISO3166-2-lvl6': 'GB-YOR',
#   'state': 'England',
#   'ISO3166-2-lvl4': 'GB-ENG',
#   'postcode': 'YO23 3QT',
#   'country': 'United Kingdom',
#   'country_code': 'gb'}]

# %%
address_df = pd.DataFrame(coord_list) #converting list of addresses to a dataframe.
address_df.head()
# Out:
#                     town         county ISO3166-2-lvl6  \
# 0                 Alford  Aberdeenshire         GB-ABD
# 1                    NaN    West Sussex         GB-WSX
# 2              Belper CP     Derbyshire         GB-DBY
# 3  Royal Burgh of Forfar          Angus         GB-ANS
# 4           Newtownabbey  County Antrim            NaN
#
#                                    state ISO3166-2-lvl4  postcode  \
# 0                        Alba / Scotland         GB-SCT  AB33 8PX
# 1                                England         GB-ENG  BN15 0RJ
# 2                                England         GB-ENG  DE56 1LB
# 3                        Alba / Scotland         GB-SCT   DD8 5QL
# 4  Northern Ireland / Tuaisceart Éireann         GB-NIR  BT36 5QA
#
#           country country_code                      road       village  ...  \
# 0  United Kingdom           gb                       NaN           NaN  ...
# 1  United Kingdom           gb  Ricardo Noise Test Track       Lancing  ...
# 2  United Kingdom           gb         Marlborough Drive  Openwoodgate  ...
# 3  United Kingdom           gb                       NaN           NaN  ...
# 4  United Kingdom           gb      Carnmoney Road North           NaN  ...
#
#   leisure building farm locality industrial club place commercial borough  \
# 0     NaN      NaN  NaN      NaN        NaN  NaN   NaN        NaN     NaN
# 1     NaN      NaN  NaN      NaN        NaN  NaN   NaN        NaN     NaN
# 2     NaN      NaN  NaN      NaN        NaN  NaN   NaN        NaN     NaN
# 3     NaN      NaN  NaN      NaN        NaN  NaN   NaN        NaN     NaN
# 4     NaN      NaN  NaN      NaN        NaN  NaN   NaN        NaN     NaN
#
#   farmyard
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 44 columns]

# %%
address_df.info() #the state values of all 402 coordinates were successfully reverse geocoded.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 44 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   town               146 non-null    object
#  1   county             316 non-null    object
#  2   ISO3166-2-lvl6     315 non-null    object
#  3   state              402 non-null    object
#  4   ISO3166-2-lvl4     402 non-null    object
#  5   postcode           381 non-null    object
#  6   country            402 non-null    object
#  7   country_code       402 non-null    object
#  8   road               323 non-null    object
#  9   village            160 non-null    object
#  10  city               222 non-null    object
#  11  isolated_dwelling  8 non-null      object
#  12  office             1 non-null      object
#  13  suburb             265 non-null    object
#  14  region             9 non-null      object
#  15  ISO3166-2-lvl5     9 non-null      object
#  16  man_made           5 non-null      object
#  17  house_number       47 non-null     object
#  18  hamlet             38 non-null     object
#  19  railway            4 non-null      object
#  20  residential        8 non-null      object
#  21  tourism            13 non-null     object
#  22  city_district      29 non-null     object
#  23  ISO3166-2-lvl8     68 non-null     object
#  24  state_district     98 non-null     object
#  25  shop               24 non-null     object
#  26  neighbourhood      34 non-null     object
#  27  municipality       15 non-null     object
#  28  quarter            16 non-null     object
#  29  amenity            58 non-null     object
#  30  historic           14 non-null     object
#  31  highway            6 non-null      object
#  32  retail             4 non-null      object
#  33  ISO3166-2-lvl      1 non-null      object
#  34  leisure            7 non-null      object
#  35  building           22 non-null     object
#  36  farm               8 non-null      object
#  37  locality           9 non-null      object
#  38  industrial         6 non-null      object
#  39  club               1 non-null      object
#  40  place              1 non-null      object
#  41  commercial         1 non-null      object
#  42  borough            1 non-null      object
#  43  farmyard           1 non-null      object
# dtypes: object(44)
# memory usage: 138.3+ KB

# %%
coord_df = pd.DataFrame(coordinates, columns=["Region","Latitude","Longitude"])
coord_df.head() #creating a dataframe of the region and coordinate values.
# Out:
#                                     Region   Latitude  Longitude
# 0            Aberdeenshire, United Kingdom  57.166667  -2.666667
# 1                     Adur, United Kingdom  50.845317  -0.293989
# 2             Amber Valley, United Kingdom  53.029038  -1.462503
# 3                    Angus, United Kingdom  56.666667  -2.916667
# 4  Antrim and Newtownabbey, United Kingdom  54.695161  -5.946966

# %%
region_df = pd.concat([coord_df, address_df], axis=1)[["Region","county","state"]]
region_df.head() #concatenating the address and region dataframes column-wise, and extracting the region and state
                 #columns of the resulting dataframe into a new dataframe.
# Out:
#                                     Region         county  \
# 0            Aberdeenshire, United Kingdom  Aberdeenshire
# 1                     Adur, United Kingdom    West Sussex
# 2             Amber Valley, United Kingdom     Derbyshire
# 3                    Angus, United Kingdom          Angus
# 4  Antrim and Newtownabbey, United Kingdom  County Antrim
#
#                                    state
# 0                        Alba / Scotland
# 1                                England
# 2                                England
# 3                        Alba / Scotland
# 4  Northern Ireland / Tuaisceart Éireann

# %%
region_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Region  402 non-null    object
#  1   county  316 non-null    object
#  2   state   402 non-null    object
# dtypes: object(3)
# memory usage: 9.5+ KB

# %%
pd.unique(region_df["state"]) #checking the unique values of the state column.
# Out:
# array(['Alba / Scotland', 'England',
#        'Northern Ireland / Tuaisceart Éireann', 'Cymru / Wales'],
#       dtype=object)

# %%
region_df['state'] = region_df['state'].replace(['Alba / Scotland',
       'Northern Ireland / Tuaisceart Éireann', 'Cymru / Wales'], ['Scotland',
       'Northern Ireland', 'Wales']) #keeping only the english version of the state names.

# %%
pd.unique(region_df["state"])
# Out:
# array(['Scotland', 'England', 'Northern Ireland', 'Wales'], dtype=object)

# %%
regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Region  405 non-null    object
# dtypes: object(1)
# memory usage: 3.3+ KB

# %%
final_reg = sqldf("select a.Region, b.state, b.county from regions a full join region_df b on (a.Region = b.Region)")
final_reg.head() #merging the new dataframe to the original regions dataframe using SQL full join, in order to retain the
                 #three locations which were not successfully geocoded.
# Out:
#                                     Region             state         county
# 0            Aberdeenshire, United Kingdom          Scotland  Aberdeenshire
# 1                     Adur, United Kingdom           England    West Sussex
# 2             Amber Valley, United Kingdom           England     Derbyshire
# 3                    Angus, United Kingdom          Scotland          Angus
# 4  Antrim and Newtownabbey, United Kingdom  Northern Ireland  County Antrim

# %%
final_reg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Region  405 non-null    object
#  1   state   402 non-null    object
#  2   county  316 non-null    object
# dtypes: object(3)
# memory usage: 9.6+ KB

# %%
sqldf("select * from final_reg where state is null")
#checking unsuccessfully geocoded regions. from google searches, all 3 locations were found to be in Northern Ireland.
# Out:
#                                               Region state county
# 0  Armagh City Banbridge and Craigavon, United Ki...  None   None
# 1            Lisburn and Castlereagh, United Kingdom  None   None
# 2                Mid and East Antrim, United Kingdom  None   None

# %%
final_reg["state"].fillna("Northern Ireland", inplace=True) #replacing NA values in "state" with "Northern Ireland".

# %%
uk_hp_index = sqldf("select a.*, b.state, b.county from uk_hpi a join final_reg b on (a.Region = b.Region)") 
#adding the state column to the original dataset using SQL join.

# %%
uk_hp_index.drop(["Region"], axis=1, inplace=True) #dropping region column.

# %% [markdown]
# ## Exporting the modified dataset to a MySQL server

# %%
engine = mysql_engine() #creating an instance of the SQL connection engine from the central module.

# %%
uk_hp_index.to_sql("uk_house_price_index", con=engine, if_exists="replace", index=None)
#saving the modified dataset as a SQL table.
# Out:
# 136125

# %%
# geolocator.reverse(coordinates[40]).raw["address"]

# %%
# coordinates[40]

# %%
# test = geolocator.reverse("53.480837, -2.244914").raw["address"]

# %%
# test["state"]

# %%
# coordinates

# %% [markdown]
# https://jharding.co.uk/list-of-uk-counties/

# %%
#counties = pd.read_csv("https://jharding.co.uk/download/433/?tmstv=1687349276")

# %%
# counties = counties[0:112] #taking only the ones that have actual info
# counties.isna().sum()

# %%
#sum(counties["County"].isin(regions["RegionName"]))

# %%
#sum(regions["RegionName"].isin(counties["County"]))

# %%
# counties

# %%
# sqldf("select a.*, b.* from counties a join regions b on (a.County = b.RegionName)")

# %%
# all_regions = pd.merge(counties, regions, left_on='County', right_on='RegionName', how='right')
# all_regions.to_csv("regions.csv")

# %%
# sqldf("select * from all_regions where RegionName is not null and County is null")

# %%
# sum(pd.notnull(all_regions["County"]))
